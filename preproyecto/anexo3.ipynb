# %%
import pandas as pd
# /preproyecto/

# Import dataset ventas final
# Corrected URL to point to the raw file on GitHub
url = "https://raw.githubusercontent.com/alex-degarate/DAnalytics/main/preproyecto/Datasets/tempo/"

df_pp_ventas = pd.read_csv( url + "pp_ventas.csv")

df_producto = pd.read_csv( url + "df_producto.csv")

df_adorno_pared = pd.read_csv( url + "df_adorno_pared.csv")

df_cuadro_decorativo = pd.read_csv( url + "df_cuadro_decorativo.csv")

# %%
df_pp_ventas.info()

df_pp_ventas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio_unit  2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 140.7+ KB
#    id_venta         producto  precio_unit  cantidad fecha_venta   categoria
# 0       410  Adorno de pared       109.64         3  2024-06-21  Decoración
# 1       620  Adorno de pared        92.16         4  2024-10-21  Decoración
# 2       780  Adorno de pared        79.13         7  2024-03-21  Decoración
# 3        50  Adorno de pared        83.10         5  2024-01-31  Decoración
# 4       260  Adorno de pared       101.48         9  2024-01-15  Decoración

# %%
df_producto.head()
# Out:
#    id_producto         producto  id_categoria          categoria
# 0            1  Adorno de pared             1         Decoración
# 1            2         Alfombra             1         Decoración
# 2            3       Aspiradora             2  Electrodomésticos
# 3            4      Auriculares             3        Electrónica
# 4            5         Batidora             2  Electrodomésticos

# %%
df_adorno_pared.head()
# Out:
#    id_venta            producto  precio_unit  cantidad fecha_venta  \
# 0       410  Adorno de pared-R3       109.64         3  2024-06-21
# 1       620  Adorno de pared-R3        92.16         4  2024-10-21
# 2       780  Adorno de pared-R2        79.13         7  2024-03-21
# 3        50  Adorno de pared-R2        83.10         5  2024-01-31
# 4       260  Adorno de pared-R3       101.48         9  2024-01-15
#
#     categoria precio_range  media_rango
# 0  Decoración       91-120       105.74
# 1  Decoración       91-120       105.74
# 2  Decoración        66-91        78.29
# 3  Decoración        66-91        78.29
# 4  Decoración       91-120       105.74

# %%
df_cuadro_decorativo.head()
# Out:
#    id_venta              producto  precio_unit  cantidad fecha_venta  \
# 0       112  Cuadro decorativo-R3        96.66         9  2024-12-19
# 1       482  Cuadro decorativo-R1        54.21         7  2024-05-31
# 2       222  Cuadro decorativo-R2        84.64         1  2024-12-21
# 3       432  Cuadro decorativo-R2        77.42        12  2024-05-30
# 4       412  Cuadro decorativo-R2        67.79         9  2024-08-24
#
#     categoria
# 0  Decoración
# 1  Decoración
# 2  Decoración
# 3  Decoración
# 4  Decoración
