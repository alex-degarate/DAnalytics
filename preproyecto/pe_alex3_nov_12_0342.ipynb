# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-degarate/DAnalytics/blob/main/preproyecto/pe_alex3_nov_12_0342.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de datos con Pyhon - Entrega         nov-12-0342
# Nombre y apellido: DE GARATE, ESTEBAN ALEJANDRO
#
# Comisión: TT252813 - 2C2025 Lunes 19 hs
#
# .

# %% [markdown]
# # Etapa 1

# %% [markdown]
# ## Import Datasets
# Actividad 1
# Los datasets actuales son el resultado del procesamiento anterior

# %%
import pandas as pd

# %%
# Import dataset ventas
# a partir de ahora vamos a trabajar con df_pp_ventas2 ver 6k
url2 ="https://raw.githubusercontent.com/alex-degarate/DAnalytics/main/preproyecto/Datasets/tempo/"
df_pp_ventas2 = pd.read_csv( url2 + "df_pp_ventas6k.csv",index_col=0 )

# %%
# a partir de ahora vamos a trabajar con producto ver 6k
df_producto = pd.read_csv( url2 + "df_producto6k.csv",index_col=0 )

df_producto7 = pd.read_csv( url2 + "df_producto7.csv",index_col=0 )

# %%
df_producto

# %%
# Import dataset clientes
df_clientes = pd.read_csv( url2 + "df_clientes6.csv",index_col=0)

# %%
# Import dataset marketing
# df_marketing = pd.read_csv( url2 + "df_marketing6.csv")
display(df_marketing.sample(10))
# Out:
#     id_camp           producto  canal  costo  fecha_ini  fecha_fin
# 5         6   Plancha de vapor   RRSS   4.02 2024-09-24 2024-11-02
# 45       46           Lavadora  Email   3.63 2024-05-12 2024-05-29
# 8         9         Candelabro   RRSS   5.32 2024-10-08 2024-11-16
# 36       37          Proyector  Email   3.22 2024-07-06 2024-07-26
# 47       48     Cámara digital  Email   6.84 2024-10-31 2024-12-09
# 46       47        Auriculares  Email   4.19 2024-06-02 2024-07-22
# 12       13           Cortinas   RRSS   5.22 2024-09-16 2024-10-15
# 1         2    Lámpara de mesa   RRSS   5.88 2024-05-30 2024-06-29
# 86       87           Batidora     TV   6.28 2024-08-27 2024-10-11
# 74       75  Jarrón decorativo     TV   4.10 2024-11-03 2024-12-25

# %%
df_pp_ventas2.head(3)
# Out:
#    id_venta  id_producto         prod_gener rango  precio_unit  cantidad  \
# 0       792          192  Cuadro decorativo    R2        69.94         5
# 1       811          293    Lámpara de mesa    R3       105.10         5
# 2      1156          353           Secadora    R3        97.96         3
#
#   fecha_venta  id_cat          categoria precio_rango
# 0  2024-01-02       1         Decoración        61-86
# 1  2024-01-02       1         Decoración       83-126
# 2  2024-01-02       2  Electrodomésticos       93-125

# %%
df_pp_ventas2

# %% [markdown]
# .
#
# ## Dataframe PRODUCTO

# %%
display(df_producto.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_producto   90 non-null     int64
#  1   producto      90 non-null     object
#  2   prod_gener    90 non-null     object
#  3   rango         90 non-null     object
#  4   id_cat        90 non-null     int64
#  5   categoria     90 non-null     object
#  6   media_rango   90 non-null     float64
#  7   precio_rango  90 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.3+ KB
# None

# %%
# Elimino la columna de prod generico que ahora esta fusionada en "producto"
#df_producto7 = df_producto7.drop(columns=['prod_gener'])

#display(df_producto7.head(31))

# reemplaza los Nan en rango por '-'
'''
nlen = len(df_producto7)
for i in range( 0, nlen, 4):
    if pd.isnull( df_producto7.iat[i, 2]):
       df_producto7.iat[i, 2] = '-'
    print(i, df_producto7.iat[i, 2])
'''
display(df_producto7.head(10))
# Out:
#    id_producto            producto       prod_gener rango  id_cat  \
# 0          100     Adorno de pared              NaN     -       1
# 1          101  Adorno de pared-R1  Adorno de pared    R1       1
# 2          102  Adorno de pared-R2  Adorno de pared    R2       1
# 3          103  Adorno de pared-R3  Adorno de pared    R3       1
# 4          110            Alfombra              NaN     -       1
# 5          111         Alfombra-R1         Alfombra    R1       1
# 6          112         Alfombra-R2         Alfombra    R2       1
# 7          113         Alfombra-R3         Alfombra    R3       1
# 8          120          Aspiradora              NaN     -       2
# 9          121       Aspiradora-R1       Aspiradora    R1       2
#
#            categoria  media_rango precio_rango
# 0         Decoración        76.14          NaN
# 1         Decoración        44.39        25-66
# 2         Decoración        78.29        66-91
# 3         Decoración       105.74       91-120
# 4         Decoración        73.88          NaN
# 5         Decoración        41.55        28-54
# 6         Decoración        71.00        54-89
# 7         Decoración       109.10       89-125
# 8  Electrodomésticos        77.71          NaN
# 9  Electrodomésticos        45.72        26-64

# %%
#df_marketing7 = pd.merge( df_marketing, df_producto7[['producto', 'id_producto']],on='producto', how='left')

# reordenamos
df_marketing7 = df_marketing7[['id_camp','id_producto','producto','canal','costo','fecha_ini','fecha_fin']]
#
# Display the first few rows of the new DataFrame to confirm the merge
display(df_marketing7.sample(10))
# Out:
#    id_camp  id_producto           producto canal  costo   fecha_ini  \
# 0        1          190  Cuadro decorativo  RRSS   5.27  2024-04-27
# 1        2          290    Lámpara de mesa  RRSS   5.88  2024-05-30
# 2        3          350           Secadora  RRSS   5.10  2024-07-24
# 3        4          240           Heladera  RRSS   4.53  2024-05-31
# 4        5          250    Horno eléctrico  RRSS   5.16  2024-08-22
#
#     fecha_fin
# 0  2024-06-04
# 1  2024-06-29
# 2  2024-08-30
# 3  2024-07-15
# 4  2024-10-17

# %%
# Display information about the new DataFrame to check for null values or data types
display(df_marketing7.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_camp      90 non-null     int64
#  1   id_producto  90 non-null     int64
#  2   producto     90 non-null     object
#  3   canal        90 non-null     object
#  4   costo        90 non-null     float64
#  5   fecha_ini    90 non-null     object
#  6   fecha_fin    90 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 5.1+ KB
# None

# %% [markdown]
# ## Dataframe VENTAS

# %%
df_pp_ventas2["categoria"].unique()

# %%
df_pp_ventas2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2997
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_venta      2998 non-null   int64
#  1   id_producto   2998 non-null   int64
#  2   prod_gener    2998 non-null   object
#  3   rango         2998 non-null   object
#  4   precio_unit   2998 non-null   float64
#  5   cantidad      2998 non-null   int64
#  6   fecha_venta   2998 non-null   object
#  7   id_cat        2998 non-null   int64
#  8   categoria     2998 non-null   object
#  9   precio_rango  2998 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 322.2+ KB

# %%
#df_pp_ventas2.sort_values("prod_gener", ascending=True)
df_pp_ventas2[ df_pp_ventas2["prod_gener"] == "Adorno de pared"].count()
# Out:
# id_venta        100
# id_producto     100
# prod_gener      100
# rango           100
# precio_unit     100
# cantidad        100
# valor_venta     100
# fecha_venta     100
# id_cat          100
# categoria       100
# precio_rango    100
# valor_venta     100
# dtype: int64

# %% [markdown]
# ## Dataframe MARKETING

# %% [markdown]
# ### Analisis exploratorio de datos

# %%
# Aplicamos info() para familiarizarnos con el dataframe
df_marketing.info()

# %%
df_marketing.head()
# Out:
#    id_camp           producto canal  costo   fecha_ini   fecha_fin
# 0        1  Cuadro decorativo  RRSS   5.27  2024-04-27  2024-06-04
# 1        2    Lámpara de mesa  RRSS   5.88  2024-05-30  2024-06-29
# 2        3           Secadora  RRSS   5.10  2024-07-24  2024-08-30
# 3        4           Heladera  RRSS   4.53  2024-05-31  2024-07-15
# 4        5    Horno eléctrico  RRSS   5.16  2024-08-22  2024-10-17

# %%
# Analizamos el campo fecha_inicio
df_marketing["fecha_ini"].sample(5)
# Out:
# 41    2024-07-14
# 65    2024-10-04
# 34    2024-07-31
# 11    2024-03-26
# 9     2024-08-19
# Name: fecha_ini, dtype: object

# %% [markdown]
# ### Calidad de los datos

# %%
df_marketing.info()

# %% [markdown]
# .
#
#
# ## Dataframe CLIENTES

# %% [markdown]
# ### Analisis exploratorio de datos

# %%
# Aplicamos info() para familiarizarnos con el dataframe
df_clientes.info()

# %%
#df_clientes[500:]

# %% [markdown]
# ###Calidad de los datos

# %%
# reemplazamos las vocales acentuadas por otras sin acento
# y (opcionalmente) podemos guardar en una nueva columna "city_normal"
import re

def replace_accented(match):
    char = match.group(0)
    mapping = {'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u'}
    return mapping.get(char, char)

# 1 y 2 funcionan OK
# 1 df_clientes['city_normal'] = df_clientes['ciudad'].str.replace(r'[áéíóú]', replace_accented, regex=True)
# 2
df_clientes['ciudad'] = df_clientes['ciudad'].str.replace(r'[áéíóú]', lambda match: replace_accented(match), regex=True)
'''
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('á','a')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('é','e')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('í','i')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('ó','o')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('ú','u')
# comparar resultados
display(df_clientes.loc[100:110,['ciudad', 'city_normal']].sample(10))
'''
display(df_clientes.loc[100:110,['ciudad']].sample(10))

# %%
# nombres con apostrofes u otros
# Esta linea busca caracteres distintos de letras y espacio
metodo1 = df_clientes[df_clientes["nombre"].str.strip().str.contains(r"[^a-zA-Z\s+]", regex=True)].count()

# Esta linea busca especificamente por apostrofe, guion medio y punto
metodo2 = df_clientes[df_clientes["nombre"].str.contains(r"['-.]", regex=True)].count()

# %% [markdown]
# .
#
# ### Dataframe VENTAS

# %%
# Convertir el campo fecha_venta a dtype datetime
#pd.to_datetime(df_pp_ventas2["fecha_venta"], format="%d/%m/%Y")
#pd.to_datetime(df_pp_ventas2["fecha_venta"], )dayfirst=True
df_pp_ventas2['fecha_venta'] = pd.to_datetime(df_pp_ventas2['fecha_venta'], format="%Y-%m-%d")

# %%
#df_pp_ventas2["fecha_venta"] = pd.to_datetime(df_pp_ventas2["fecha_venta"], format="%d/%m/%Y")
df_pp_ventas2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2997
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_venta      2998 non-null   int64
#  1   id_producto   2998 non-null   int64
#  2   prod_gener    2998 non-null   object
#  3   rango         2998 non-null   object
#  4   precio_unit   2998 non-null   float64
#  5   cantidad      2998 non-null   int64
#  6   fecha_venta   2998 non-null   datetime64[ns]
#  7   id_cat        2998 non-null   int64
#  8   categoria     2998 non-null   object
#  9   precio_rango  2998 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 322.2+ KB

# %% [markdown]
# .
#
#
# ================================================================================

# %% [markdown]
# ### Dataframe marketing

# %% [markdown]
# ACCIONES
#
# Convertir el campo fecha_inicio a dtype = datetime
# Convertir el campo fecha_fin    a dtype = datetime

# %%
# Convertir el campo fecha_inicio a dtype datetime
#df_marketing['fecha_ini'] = pd.to_datetime(df_marketing['fecha_ini'], format="%d/%m/%Y") NO FUNCA
df_marketing['fecha_ini'] = pd.to_datetime(df_marketing['fecha_ini'], format="%Y-%m-%d")

# %%
# Convertir el campo fecha_fin a dtype datetime
df_marketing['fecha_fin'] = pd.to_datetime(df_marketing['fecha_fin'], format="%Y-%m-%d")

# %%
# Validamos los cambios
df_marketing[["fecha_ini","fecha_fin"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fecha_ini  90 non-null     datetime64[ns]
#  1   fecha_fin  90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 1.5 KB

# %% [markdown]
#
#
# ### Dataframe clientes

# %%
df_clientes.info()

# %%
df_clientes.head()
# Out:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahia Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65

# %%
# @title
# Hacemos una copia del df_clientes
df_clientes_final = df_clientes.copy()

# Guardamos la copia a disco
df_clientes_final.to_csv('df_clientes_final.csv', index=False)

# %% [markdown]
# .
#
# ## **Transformación de datos**
# Actividad 2 - Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.

# %%
# Transformación:
# Calculamos el valor de cada venta = precio_unit * cantidad

# Agregamos una nueva columna  valor_venta = monto
df_pp_ventas2["valor_venta"] = df_pp_ventas2["precio_unit"] * df_pp_ventas2["cantidad"]

# %%
# Visualizamos
df_pp_ventas2.head(2)
# Out:
#    id_venta  id_producto         prod_gener rango  precio_unit  cantidad  \
# 0       792          192  Cuadro decorativo    R2        69.94         5
# 1       811          293    Lámpara de mesa    R3       105.10         5
#
#   fecha_venta  id_cat   categoria precio_rango  valor_venta
# 0  2024-01-02       1  Decoración        61-86        349.7
# 1  2024-01-02       1  Decoración       83-126        525.5

# %%
# Agregación:
# Agrupar valor_venta por producto
# Sumamos las ventas dentro de cada grupo
tabla_ventas = (df_pp_ventas2.groupby("prod_gener", as_index=False)["valor_venta"].sum())
tabla_ventas.head()

# %%
# Usemos describe para analizar algunos valores del dataframe resultante
tabla_ventas.describe()

# %% [markdown]
# ### Alto Rendimiento
# Los productos de alto rendimiento son aquellos que maximizan su utilidad, rentabilidad o eficiencia (se tomará quartil 75 )

# %%
# Calcular el percentil 75 (umbral de alto rendimiento)
umbral_ventas = tabla_ventas["valor_venta"].quantile(0.75)

umbral_ventas #  51092.96
# Out:
# np.float64(51092.96)

# %%
# Identificar productos que superan el umbral
# productos_top = tabla_ventas.query("valor_venta >= @umbral")
productos_top = tabla_ventas[tabla_ventas["valor_venta"] >= umbral_ventas]
productos_top = productos_top.sort_values(by="valor_venta", ascending=False)
productos_top.head(8)

# %%
ventas_totales = df_pp_ventas2["valor_venta"].sum()
print(f"El total de ventas es: ${ventas_totales: ,.02f}")
# Out:
# El total de ventas es: $ 1,467,093.52

# %% [markdown]
# ## Productos Top

# %%
# @title
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el gráfico de torta
plt.figure(figsize=(4, 4))
sns.set_style("whitegrid")
explode = [0.1, 0,0,0,0,0,0,0]
wedges, texts, autotexts = plt.pie(productos_top['valor_venta'], labels=productos_top['prod_gener'],
                                   autopct='%1.1f%%', explode=explode, startangle=90)

# Cambiar los atributos del título
plt.title('Venta Productos Top', fontsize=14, color='darkblue', style='italic')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Cambiar el color de los porcentajes a blanco
for autotext in autotexts:
    autotext.set_color('white')

plt.show()

# %%
# @title
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el gráfico de barras horizontal
plt.figure(figsize=(9, 5))
sns.barplot(x='valor_venta', y='prod_gener', data=productos_top, palette='viridis_r', hue='prod_gener')

# Cambiar los atributos del título
plt.title('Venta de Productos Top \n', fontsize=14, color='darkblue', style='italic')
plt.xlabel('\nValor de Venta (en miles)',fontsize=10, color="brown")
plt.ylabel('Producto', fontsize=12, color="brown")

# Definir una función de formato para el eje x
def thousands_formatter(x, pos):
    return f'{int(x/1000)}k'

# Aplicar el formateador al eje x
formatter = mticker.FuncFormatter(thousands_formatter)
plt.gca().xaxis.set_major_formatter(formatter)

# Añadir una anotación para el total de ventas en la parte inferior
plt.text(0.97, 0.05, f'Total Ventas: ${ventas_totales:,.2f}', transform=plt.gca().transAxes,
         fontsize=11, verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

# Agregar un marcador para umbral_ventas en el eje X
plt.axvline(x=umbral_ventas, color='red', linestyle='--', linewidth=0.9,
            label=f'Umbral Ventas:\n${umbral_ventas:,.2f}')
plt.legend(loc='lower right', bbox_to_anchor=(1.0, -0.22),fontsize=8)

plt.tight_layout() # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# <!-- Inserta aquí tus comentarios o notas. Por ejemplo: -->
#
# ### Observaciones Importantes
#
# *   Este es un comentario importante sobre el análisis de ventas.
# *   Podríamos considerar estrategias de marketing específicas para los productos de alto rendimiento.

# %% [markdown]
# ### Agregación
#
# ### Resumir las ventas por categoría de producto y analizar los ingresos generados.

# %%
# Agrupamos por categoria y agregamos el total valor_venta/categoria
# (solo son 3 categorías )
ventas_categoria = df_pp_ventas2.groupby("categoria", as_index=False)["valor_venta"].sum()

# Ordenar y mostrar los resultados
ventas_categoria.sort_values(by="valor_venta", ascending=False, inplace=True)

ventas_categoria.head()

# %% [markdown]
# ### Ventas por Categoria

# %%
# @title
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el gráfico de torta
plt.figure(figsize=(5, 5))
sns.set_style("whitegrid")
explode = [0, 0.1, 0]
wedges, texts, autotexts = plt.pie(ventas_categoria['valor_venta'], labels=ventas_categoria['categoria'], autopct='%1.1f%%', explode=explode, startangle=90)

# Cambiar los atributos del título
plt.title('Distribución de Ventas por Categoría', fontsize=14, color='darkblue', style='italic')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Cambiar el color de los porcentajes a blanco
for autotext in autotexts:
    autotext.set_color('white')

plt.show()

# %% [markdown]
# A pesar de estar equilibradas las ventas, se puede ver que la categoría 'Electrodomésticos' representa una mayor parte de las ventas.

# %% [markdown]
# .
#
#
# ## Integración de datos
# Actividad 4 - Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %%
# ordenamos columnas
df_pp_ventas2 = df_pp_ventas2[['id_venta', 'id_producto', 'prod_gener','rango','precio_unit',
       'cantidad', 'valor_venta','fecha_venta','id_cat','categoria','precio_rango',	'valor_venta']]
df_pp_ventas2.head(2)
# Out:
#    id_venta  id_producto         prod_gener rango  precio_unit  cantidad  \
# 0       792          192  Cuadro decorativo    R2        69.94         5
# 1       811          293    Lámpara de mesa    R3       105.10         5
#
#    valor_venta fecha_venta  id_cat   categoria precio_rango  valor_venta
# 0        349.7  2024-01-02       1  Decoración        61-86        349.7
# 1        525.5  2024-01-02       1  Decoración       83-126        525.5

# %%
df_pp_ventas2.info()

# %%
# df_marketing.info()

df_marketing.head()
# Out:
#    id_camp           producto canal  costo  fecha_ini  fecha_fin
# 0        1  Cuadro decorativo  RRSS   5.27 2024-04-27 2024-06-04
# 1        2    Lámpara de mesa  RRSS   5.88 2024-05-30 2024-06-29
# 2        3           Secadora  RRSS   5.10 2024-07-24 2024-08-30
# 3        4           Heladera  RRSS   4.53 2024-05-31 2024-07-15
# 4        5    Horno eléctrico  RRSS   5.16 2024-08-22 2024-10-17

# %%
# @title
# Vemos la cantidad de productos unicos en ventas
# df_pp_ventas2["prod_gener"].nunique() # 30

# %%
# @title
# Vemos la cantidad de productos unicos en marketing
# df_marketing["producto"].nunique()   # 30

# %%
# @title
# Listamos los registros de ventas ordenados por producto, forma ascendente
df_pp_ventas2.sort_values(by="prod_gener", ascending=True )

# %%
# Listamos los registros de marketing ordenados por producto, forma ascendente
#df_marketing2 = df_marketing.sort_values(by="producto", ascending=True)
df_marketing.sort_values(by=["producto","canal"])

df_marketing.head(6)
# Out:
#    id_camp           producto canal  costo  fecha_ini  fecha_fin
# 0        1  Cuadro decorativo  RRSS   5.27 2024-04-27 2024-06-04
# 1        2    Lámpara de mesa  RRSS   5.88 2024-05-30 2024-06-29
# 2        3           Secadora  RRSS   5.10 2024-07-24 2024-08-30
# 3        4           Heladera  RRSS   4.53 2024-05-31 2024-07-15
# 4        5    Horno eléctrico  RRSS   5.16 2024-08-22 2024-10-17
# 5        6   Plancha de vapor  RRSS   4.02 2024-09-24 2024-11-02

# %%
# Para evitar duplicados, habria que agrupar marketing antes de hacer el merge
# (a costa de perder la fecha)
df_marketing_avg = df_marketing.groupby(["producto"], as_index=False)["costo"].mean()
df_marketing_avg
# Out:
#                   producto     costo
# 0          Adorno de pared  4.683333
# 1                 Alfombra  5.820000
# 2               Aspiradora  5.486667
# 3              Auriculares  5.080000
# 4                 Batidora  5.093333
# 5                 Cafetera  6.053333
# 6               Candelabro  4.883333
# 7   Consola de videojuegos  4.256667
# 8                 Cortinas  5.786667
# 9        Cuadro decorativo  5.283333
# 10          Cámara digital  5.466667
# 11   Elementos de cerámica  5.623333
# 12       Espejo decorativo  4.963333
# 13      Freidora eléctrica  4.520000
# 14                Heladera  4.370000
# 15         Horno eléctrico  4.630000
# 16       Jarrón decorativo  4.423333
# 17                  Laptop  5.063333
# 18                Lavadora  3.950000
# 19         Lámpara de mesa  5.310000
# 20              Microondas  4.730000
# 21     Parlantes Bluetooth  4.456667
# 22        Plancha de vapor  4.706667
# 23               Proyector  4.156667
# 24       Rincón de plantas  5.483333
# 25                Secadora  4.863333
# 26              SmartWatch  4.833333
# 27              Smartphone  5.266667
# 28                  Tablet  4.240000
# 29               Televisor  4.376667

# %%
# Unir los datasets ventas y marketing por columna 'producto'

# Aqui tenemos dos caminos, unir df_ventas con df_marketing que tiene duplicados
# met 1
ventas_marketing1 = pd.merge(df_pp_ventas2, df_marketing, on="producto", how="left")

# O, unir df_ventas con df_marketing_avg que no tiene duplicados, pero no tiene fechas
# met 2
ventas_marketing_avg = pd.merge(df_pp_ventas2, df_marketing_avg, on="producto", how="inner")

# %%
ventas_marketing1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8994 entries, 0 to 8993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_venta      8994 non-null   int64
#  1   producto      8994 non-null   object
#  2   precio_unit   8994 non-null   float64
#  3   cantidad      8994 non-null   int64
#  4   fecha_venta   8994 non-null   datetime64[ns]
#  5   categoria     8994 non-null   object
#  6   valor_venta   8994 non-null   float64
#  7   id_campanha   8994 non-null   int64
#  8   canal         8994 non-null   object
#  9   costo         8994 non-null   float64
#  10  fecha_inicio  8994 non-null   datetime64[ns]
#  11  fecha_fin     8994 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(3), object(3)
# memory usage: 843.3+ KB

# %%
ventas_marketing_avg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio_unit  2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
#  6   valor_venta  2998 non-null   float64
#  7   costo        2998 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 187.5+ KB

# %%
# Verificar coincidencias (muestra)
ventas_marketing1.sort_values(by=["producto", "precio_unit"], ascending=True)
ventas_marketing1.head(6)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 1       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 2       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 3       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
# 4       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
# 5       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
#
#    valor_venta  id_campanha  canal  costo fecha_inicio  fecha_fin
# 0        349.7            1   RRSS   5.27   2024-04-27 2024-06-04
# 1        349.7           31  Email   5.28   2024-08-15 2024-09-12
# 2        349.7           61     TV   5.30   2024-11-05 2024-12-23
# 3        525.5           32  Email   5.54   2024-03-28 2024-04-20
# 4        525.5            2   RRSS   5.88   2024-05-30 2024-06-29
# 5        525.5           62     TV   4.51   2024-08-26 2024-10-07

# %%
# Nota1: si unieron ventas con marketing, obtienen 8994 registros
# Nota2: si unieron ventas con marketing_avg obtienen 2998 registros

# %% [markdown]
# ### Analizamos el impacto de la campaña

# %%
# Nos quedamos solo con los registros de ventas durante la campaña de marketing
ganancias_marketing = ventas_marketing1.query("fecha_venta > fecha_inicio & fecha_venta < fecha_fin")

# Nota: si trabajan con el DF marketing1 pueden aplicar el filtro,
# si trabajan con dataframe marketing_avg, al no tener fecha, no apliquen el filtro.


# Seleccionamos solo los campos que nos interesan: "producto", "valor_venta", "costo"
ganancias_marketing = ganancias_marketing[["producto", "valor_venta", "costo"]]
ganancias_marketing.sort_values(by="producto", ascending=True)
ganancias_marketing.head(6)
# Out:
#              producto  valor_venta  costo
# 2091  Adorno de pared       553.91   4.81
# 2124  Adorno de pared       579.54   4.81
# 2160  Adorno de pared       286.68   4.81
# 2256  Adorno de pared       831.20   4.81
# 2286  Lámpara de mesa        44.88   5.54
# 2298           Tablet       394.24   3.40

# %%
# Agrupamos por producto y hacemos una agregación por "valor de venta" y "costo"
ganancias_marketing = ganancias_marketing.groupby("producto")[["valor_venta","costo"]].sum()
ganancias_marketing
# Out:
#                         valor_venta   costo
# producto
# Adorno de pared            15110.72  129.80
# Alfombra                   14786.14  172.57
# Aspiradora                 12844.78  163.92
# Auriculares                19840.99  201.70
# Batidora                   22137.37  212.08
# Cafetera                   14459.17  160.84
# Candelabro                  5700.53   63.08
# Consola de videojuegos      7785.49   68.69
# Cortinas                   14623.15  166.43
# Cuadro decorativo          17482.27  174.36
# Cámara digital             19705.88  229.58
# Elementos de cerámica       8024.73  113.70
# Espejo decorativo          10882.18  114.30
# Freidora eléctrica          7076.03   73.71
# Heladera                    8233.36   60.12
# Horno eléctrico            17244.82  154.30
# Jarrón decorativo          14657.18  132.15
# Laptop                     11824.25  115.50
# Lavadora                    8738.74   70.89
# Lámpara de mesa            17461.57  229.31
# Microondas                 14865.68  104.89
# Parlantes Bluetooth        17942.96  144.45
# Plancha de vapor           11776.61  148.97
# Proyector                  11788.86  109.37
# Rincón de plantas           8098.52   77.22
# Secadora                    6057.90   66.55
# SmartWatch                 13603.77  124.18
# Smartphone                 12782.03  144.81
# Tablet                     13719.93  133.12
# Televisor                  11508.62   86.81

# %%
# Generamos una nueva columna con la diferencia entre lo vendido y lo invertido en la campaña
ganancias_marketing["ganancia_neta"] = ganancias_marketing['valor_venta'] - ganancias_marketing['costo']
ganancias_marketing = ganancias_marketing.sort_values(by="ganancia_neta", ascending=False)

ganancias_marketing.head()
# Out:
#                      valor_venta   costo  ganancia_neta
# producto
# Batidora                22137.37  212.08       21925.29
# Auriculares             19840.99  201.70       19639.29
# Cámara digital          19705.88  229.58       19476.30
# Parlantes Bluetooth     17942.96  144.45       17798.51
# Cuadro decorativo       17482.27  174.36       17307.91

# %%
#
# Crear un gráfico de barras apilado para comparar valor_venta y costo por producto

ganancias_marketing[["valor_venta", "costo"]].plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Comparación de Valor de Venta y Costo por Producto")
plt.xlabel("Producto")
plt.ylabel("Monto")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Solución al problema de los duplicados**

# %%
# Hacemos el merge entre marketing y ventas por columna producto
marketing_ventas = pd.merge(df_marketing, df_pp_ventas2, on="producto", how="inner")
marketing_ventas.sort_values(by="producto", ascending=True)
marketing_ventas.head(6)
# Out:
#    id_campanha         producto canal  costo fecha_inicio  fecha_fin  \
# 0           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 1           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 2           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 3           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 4           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 5           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
#
#    id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta
# 0       630        71.99         9  2024-01-04  Decoración       647.91
# 1       560        57.62         6  2024-01-07  Decoración       345.72
# 2       830        67.23        10  2024-01-10  Decoración       672.30
# 3        20        90.21         2  2024-01-14  Decoración       180.42
# 4       260       101.48         9  2024-01-15  Decoración       913.32
# 5       430        81.76         5  2024-01-18  Decoración       408.80

# %%
# filtramos solo aquellos productos que se hayan vendido dentro de la campaña
marketing_ventas_pp1 = marketing_ventas.query("fecha_venta > fecha_inicio & fecha_venta < fecha_fin")
marketing_ventas_pp1.head(6)
# Out:
#     id_campanha         producto canal  costo fecha_inicio  fecha_fin  \
# 24           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 25           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 26           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 27           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 28           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 29           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
#
#     id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta
# 24       780        79.13         7  2024-03-21  Decoración       553.91
# 25       270        96.59         6  2024-03-22  Decoración       579.54
# 26       210        71.67         4  2024-03-24  Decoración       286.68
# 27       730       103.90         8  2024-03-28  Decoración       831.20
# 28       390        87.52         8  2024-04-01  Decoración       700.16
# 29       570        64.18         7  2024-04-03  Decoración       449.26

# %%
# Calculamos el total_ventas por producto haciendo valor_venta * cantidad
marketing_ventas_pp2 = marketing_ventas_pp1.copy() # para eliminar la advertencia
#marketing_ventas_pp2.info()

marketing_ventas_pp2["total_venta"] = (
    marketing_ventas_pp2["valor_venta"] * marketing_ventas_pp2["cantidad"]
)
marketing_ventas_pp2.head(6)
# Out:
#     id_campanha         producto canal  costo fecha_inicio  fecha_fin  \
# 24           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 25           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 26           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 27           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 28           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
# 29           74  Adorno de pared    TV   4.81   2024-03-20 2024-05-03
#
#     id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta  \
# 24       780        79.13         7  2024-03-21  Decoración       553.91
# 25       270        96.59         6  2024-03-22  Decoración       579.54
# 26       210        71.67         4  2024-03-24  Decoración       286.68
# 27       730       103.90         8  2024-03-28  Decoración       831.20
# 28       390        87.52         8  2024-04-01  Decoración       700.16
# 29       570        64.18         7  2024-04-03  Decoración       449.26
#
#     total_venta
# 24      3877.37
# 25      3477.24
# 26      1146.72
# 27      6649.60
# 28      5601.28
# 29      3144.82

# %%
# Agrupamos el dataframe por producto  usando agg

# Agregar total_venta como el promedio, elimina el impacto de los datos duplicados
# Y seguimos agregando costo como la suma de lo invertido en cada canal
ganancias_marketing = marketing_ventas_pp2.groupby("producto").agg(
    {
        "total_venta": "mean",
        "costo": "sum",
    }
)
#ganancias_marketing

# %%
# A partir de venta_total y costo, calculamos la ganancia obtenida
ganancias_marketing["ganancia"] = ganancias_marketing["total_venta"]- ganancias_marketing["costo"]
ganancias_marketing = ganancias_marketing.sort_values(by="ganancia", ascending=False)
ganancias_marketing.head(3)
# Out:
#             total_venta   costo     ganancia
# producto
# Microondas  6164.674783  104.89  6059.784783
# Heladera    5786.587143   60.12  5726.467143
# Cafetera    5388.738000  160.84  5227.898000

# %%
# Creamos un gráfico de barras apilado para comparar valor_venta y costo por producto
ganancias_marketing[["total_venta", "costo"]].plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Comparación de Valor de Venta y Costo por Producto")
plt.xlabel("Producto")
plt.ylabel("Monto")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
'''
# Estilo
# Usamoe set_theme para ajustar los estilos del lineplo
# Cuidado: se anula si pasamos 'color' como argumento dentro de lineplot
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="talk",          # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="deep"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Línea que une los puntos
sns.lineplot(data=df, x="Mes", y="Ventas")

# Ticks (valores de eje)
plt.tick_params(axis='both', labelsize=10)

# Etiquetas y título
plt.title('Ventas mensuales (puntos unidos)')
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas', fontsize=12)
plt.tight_layout()
plt.show()
''
