# %% [markdown]
# # Actividades

# %% [markdown]
# ## Actividad 1

# %% [markdown]
#   Creá tu propio bloque de texto. Utiliza:
#   - formatos de texto
#   - links
#   - al menos una imagen de tu carpeta Drive

# %% [markdown]
# # **ACTIVIDAD EN LA PALE**
#
# **negrita**
#
# *italica*
#
# Enlace: https://drive.google.com/file/d/1e5ze3qgl3IAHruzMUoWCTcIesIZkEsSr
#
#
# '<img src="https://drive.google.com/file/d/1e5ze3qgl3IAHruzMUoWCTcIesIZkEsSr/view?usp=drive_link">'
#
# '<img src="https://drive.google.com/uc?=1e5ze3qgl3IAHruzMUoWCTcIesIZkEsSr">'

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# Creá un bloque de código con un programa que pida un número por teclado, y responda si es par o impar. Ejecutalo.

# %%
numero = int(input("Ingrese un número: "))
if numero % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")
# Out:
# Ingrese un número: 13
# El número es impar
