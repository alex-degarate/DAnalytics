# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-degarate/DAnalytics/blob/main/proentrega/entrega_alex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de datos con Pyhon - Entrega 3
# Nombre y apellido: DE GARATE, ESTEBAN ALEJANDRO
#
# Comisión: TT252813 - 2C2025 Lunes 19 hs
#
# .

# %% [markdown]
# # Etapa 1

# %% [markdown]
# ## Script básico
# Actividades 2 y 3

# %%
# Generamos una lista de diccionarios que contenga algunos datos
ventas = [
  {'producto': 'notebook', 'precio': 1500.0, 'cantidad': 3},
  {'producto': 'monitor', 'precio': 500.0, 'cantidad': 5},
  {'producto': 'mouse', 'precio': 20.0, 'cantidad': 15}
]

# %%
# Calculamos las ventas acumuladas - map
venta_acumuladas = sum( map( lambda venta: venta["precio"] * venta["cantidad"], ventas))
venta_acumuladas
# Out:
# 7300.0

# %%
# Calculamos las ventas acumuladas - listas por comprensión
venta_acumuladas = sum( [venta["precio"] * venta["cantidad"] for venta in ventas])
venta_acumuladas
# Out:
# 7300.0

# %% [markdown]
# ## Import Datasets
# Actividad 1

# %%
import pandas as pd

# %%
# Import dataset ventas
url = "https://github.com/alex-degarate/TT-2C2025-Data-Analitycs-Notebooks/raw/refs/heads/main/PreEntrega/Datasets/"
df_ventas = pd.read_csv( url + "ventas.csv")

# %%
# Import dataset clientes
df_clientes = pd.read_csv( url + "clientes.csv")

# %%
# Import dataset marketing
df_marketing = pd.read_csv( url + "marketing.csv")

# %%
df_ventas.head(3)
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos

# %% [markdown]
# ## Dataframe VENTAS

# %% [markdown]
# ### Análisis exploratorio de **datos**
# Actividad 4

# %% [markdown]
# Aplicamos los métodos de EDA vistos en clase, `info`, `columns`, `dtypes`, `head`, `tail`, `sample`, `unique`, `value_counts`, `describe`, `duplicated`, `isnull`, etc. y documentamos las observaciones:

# %%
# Aplicamos info() para familiarizarnos con el dataframe
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
# Visualizamos los primeros registros con head()
# también podemos usar tail() para visualizar los últimos
df_ventas.head()

display(df_ventas.head())
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos

# %%
# Usar sample() para tomar registros al azar
df_ventas.sample(5)
# Out:
#       id_venta               producto   precio  cantidad fecha_venta  \
# 1228       660        Adorno de pared   $71.13       9.0  16/05/2024
# 806       1611     Freidora eléctrica   $82.46       4.0  03/04/2024
# 2972       497  Elementos de cerámica  $124.16       4.0  23/12/2024
# 2520      1601     Freidora eléctrica   $32.54      11.0  27/10/2024
# 773        221        Lámpara de mesa   $41.81       9.0  31/03/2024
#
#               categoria
# 1228         Decoración
# 806   Electrodomésticos
# 2972         Decoración
# 2520  Electrodomésticos
# 773          Decoración

# %%
# Analizamos el campo precio
# Si es numerico se puede aplicar describe()
df_ventas["precio"].sample(5)
# Out:
# 469     $113.84
# 86      $117.43
# 778      $84.29
# 2484     $26.34
# 2096     $38.12
# Name: precio, dtype: object

# %%
# Analizamos el campo cantidad
# si es numerico se puede aplicar describe()
df_ventas["cantidad"].sample(5)
# Out:
# 1244    11.0
# 1691     7.0
# 2332    12.0
# 419      1.0
# 967      7.0
# Name: cantidad, dtype: float64

# %%
# Analizamos el campo fecha_venta
df_ventas["fecha_venta"].sample(5)
# Out:
# 1480    15/06/2024
# 292     03/02/2024
# 2459    20/10/2024
# 2750    26/11/2024
# 1609    03/07/2024
# Name: fecha_venta, dtype: object

# %%
# Analizamos el campo categoria
# Probar con value_counts y unique
df_ventas["categoria"].value_counts()
# Out:
# categoria
# Decoración           1015
# Electrónica          1012
# Electrodomésticos    1008
# Name: count, dtype: int64

# %%
df_ventas["categoria"].unique()
# Out:
# array(['Decoración', 'Electrodomésticos', 'Electrónica'], dtype=object)

# %% [markdown]
# ### Calidad de datos
# Actividad 5

# %%
# Buscamos registros duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(35)

# %%
# Visualizamos los duplicados
# keep: 'first', 'last', False
df_ventas[df_ventas.duplicated(keep=False)].sort_values(by="id_venta")
# Out:
#      id_venta           producto  precio  cantidad fecha_venta    categoria
# 820        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 826        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 832       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 844       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 878       204  Jarrón decorativo  $94.75       1.0  08/04/2024   Decoración
# ..        ...                ...     ...       ...         ...          ...
# 830      2545        Auriculares  $32.81      11.0  05/04/2024  Electrónica
# 883      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 889      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 831      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
# 825      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
#
# [70 rows x 6 columns]

# %%
# Buscamos datos nulos
df_ventas.isnull().sum()
# Out:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64

# %%
# Visualizar los nulos
# df_ventas[df_ventas.isnull().any(axis=1)]
nulos_lista = df_ventas[df_ventas.isnull().any(axis=1)]
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
#      id_venta               producto precio  cantidad fecha_venta    categoria
# 136       627  Elementos de cerámica    NaN       NaN  17/01/2024   Decoración
# 139      2171    Parlantes Bluetooth    NaN       NaN  17/01/2024  Electrónica

# %%
# Hay 2 registros con nulos, en el mismo registro, los campos "precio" y "cantidad son nulos
# No se pueden rescatar y van a ser eliminados
nulos_numero  = len( nulos_lista)
nulos_porcentaje = nulos_numero * 100 / len(df_ventas)
print(f"Numero de nulos: {nulos_numero } registros")
print(f"Porcentaje de nulos: {nulos_porcentaje:.2f}% registros")
# Out:
# Numero de nulos: 2 registros
# Porcentaje de nulos: 0.07% registros

# %%
# Analizar los precios de los NaN a ver que opciones tenemos
# df_ventas[df_ventas["producto"]=="Elementos de cerámica"]
# df_ventas["producto"].value_counts()
df_ventas["producto"].unique()
# Out:
# array(['Cuadro decorativo', 'Lámpara de mesa', 'Secadora', 'Heladera',
#        'Horno eléctrico', 'Plancha de vapor', 'Proyector',
#        'Rincón de plantas', 'Candelabro', 'Aspiradora',
#        'Freidora eléctrica', 'Tablet', 'Cortinas', 'Adorno de pared',
#        'Jarrón decorativo', 'Lavadora', 'Auriculares', 'Cámara digital',
#        'Cafetera', 'Consola de videojuegos', 'Smartphone',
#        'Elementos de cerámica', 'Espejo decorativo',
#        'Parlantes Bluetooth', 'SmartWatch', 'Microondas', 'Batidora',
#        'Alfombra', 'Televisor', 'Laptop'], dtype=object)

# %% [markdown]
# ### Observaciones: VENTAS

# %% [markdown]
# * Cantidad de registros originales: 3035
# * Columnas/campos originales: 6
# * 35 registros duplicados &emsp; => eliminarlos
# *  2 registros con datos nulos: id:[136, 139], < 0.1 % total &emsp; =>  dropna
# * Campo precio: tipo objeto con `$`, removerlo y luego cambiar el dtype a float64
# * Campo fecha: ajustar a dtype datetime

# %% [markdown]
# ## Dataframe MARKETING

# %% [markdown]
# ### Analisis exploratorio de datos

# %% [markdown]
# Aplicamos los métodos de EDA vistos en clase, `info`, `columns`, `dtypes`, `head`, `tail`, `sample`, `unique`, `value_counts`, `describe`, `duplicated`, `isnull`, etc. y documentamos las observaciones:

# %%
# Aplicamos info() para familiarizarnos con el dataframe
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
# Visualizamos los primeros registros con head()
# también podemos usar tail() para visualizar los últimos
pd.set_option('display.max_rows', None)
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024

# %%
# Analizamos el campo costo
df_marketing["costo"].sample(5)
# Out:
# 54    5.16
# 60    5.22
# 37    5.46
# 75    4.64
# 2     5.54
# Name: costo, dtype: float64

# %%
# Analizamos el campo fecha_inicio
df_marketing["fecha_inicio"].sample(5)
# Out:
# 72    23/10/2024
# 64    25/09/2024
# 56    27/08/2024
# 57    28/08/2024
# 74    01/11/2024
# Name: fecha_inicio, dtype: object

# %%
# Analizamos el campo fecha_fin
df_marketing["fecha_fin"].sample(5)
# Out:
# 80     13/1/2025
# 3     16/05/2024
# 79     6/12/2024
# 59    30/09/2024
# 55    07/10/2024
# Name: fecha_fin, dtype: object

# %% [markdown]
# ### Calidad de los datos

# %%
# Buscamos registros duplicados
df_marketing.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %% [markdown]
# .
#
# ### Observaciones: MARKETING
#
# El dataframe DF_MARKETING tiene 90 registros
#
# No hay registros duplicados
#
# El campo fecha_inicio es objeto &emsp; => cambiar a dtype datetime
#
# El campo fecha_fin &emsp; es objeto &emsp; => cambiar a dtype datetime

# %% [markdown]
# .
#
#
# ## Dataframe CLIENTES

# %% [markdown]
# ### Analisis exploratorio de datos

# %%
# Aplicamos info() para familiarizarnos con el dataframe
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
#df_clientes[500:]

# %%
# Visualizamos los primeros registros con head()
df_clientes.head(1)
# Out:
#    id_cliente           nombre  edad         ciudad  ingresos
# 0           1  Aloysia Screase    44  Mar del Plata  42294.68

# %%
# Buscamos registros duplicados
df_clientes.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Buscamos datos nulos
df_clientes.isnull().sum()
# Out:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64

# %% [markdown]
# .
#
#
# ### Observaciones
#
# El dataframe CLIENTES tiene 567 registros.
#
# No hay registros duplicados
#
# No hay registros con valores nulos
#
# El campo ciudad tiene ciudades con vocales acentuadas (poner vocales sin acento)
#
# El campo nombre tiene nombres con apostrofe (sacar apostrofe)

# %% [markdown]
# ###Calidad de los datos

# %%
# visualizamos las ciudades con vocales acentuadas y tilde (áéíóúñ)
ciudades_acentos = df_clientes[df_clientes["ciudad"].str.contains(r'[áéíóúñ]',regex=True)]

#display(ciudades_acentos.head())
# df_clientes[df_clientes["ciudad"].str.contains('á')].count()     # => 39
# df_clientes[df_clientes["ciudad"].str.contains('é')].count()     # => 0
# df_clientes[df_clientes["ciudad"].str.contains('í')].count()     # => 44
# df_clientes[df_clientes["ciudad"].str.contains('ó')].count()     # => 49
# df_clientes[df_clientes["ciudad"].str.contains('ú')].count()     # => 0
# df_clientes[df_clientes["ciudad"].str.contains('ñ')].count()     # => 0

ciudades_acentos.count()
# Out:
# id_cliente    132
# nombre        132
# edad          132
# ciudad        132
# ingresos      132
# dtype: int64

# %%
# reemplazamos las vocales acentuadas por otras sin acento
# y (opcionalmente) podemos guardar en una nueva columna "city_normal"
import re

def replace_accented(match):
    char = match.group(0)
    mapping = {'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u'}
    return mapping.get(char, char)

# 1 y 2 funcionan OK
# 1 df_clientes['city_normal'] = df_clientes['ciudad'].str.replace(r'[áéíóú]', replace_accented, regex=True)
# 2
df_clientes['ciudad'] = df_clientes['ciudad'].str.replace(r'[áéíóú]', lambda match: replace_accented(match), regex=True)
'''
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('á','a')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('é','e')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('í','i')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('ó','o')
df_clientes['city_normal'] = df_clientes['ciudad'].str.replace('ú','u')
# comparar resultados
display(df_clientes.loc[100:110,['ciudad', 'city_normal']].sample(10))
'''
display(df_clientes.loc[100:110,['ciudad']].sample(10))
# Out:
#                     ciudad
# 108           Buenos Aires
# 102  San Miguel de Tucuman
# 109          Mar del Plata
# 105           Bahia Blanca
# 104                  Merlo
# 100                  Merlo
# 110          Mar del Plata
# 103                Posadas
# 101                  Salta
# 107          Mar del Plata

# %%
# nombres con apostrofes u otros
# Esta linea busca caracteres distintos de letras y espacio
metodo1 = df_clientes[df_clientes["nombre"].str.strip().str.contains(r"[^a-zA-Z\s+]", regex=True)].count()

# Esta linea busca especificamente por apostrofe, guion medio y punto
metodo2 = df_clientes[df_clientes["nombre"].str.contains(r"['-.]", regex=True)].count()

print(f"Metodo 1:\n {metodo1}")
print(f"\nMetodo 2:\n {metodo2}")
# Out:
# Metodo 1:
#  id_cliente    15
# nombre        15
# edad          15
# ciudad        15
# ingresos      15
# dtype: int64
#
# Metodo 2:
#  id_cliente    15
# nombre        15
# edad          15
# ciudad        15
# ingresos      15
# dtype: int64

# %% [markdown]
# .
#
# # Etapa 2

# %% [markdown]
# ## Limpieza de datos
# Actividad 1 - Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.

# %% [markdown]
# .
#
# ### Dataframe VENTAS

# %% [markdown]
# * 35 duplicados, eliminarlos - se eliminaron 35 duplicados &emsp; => Ok
# * Algunos nulos (2), 1% del faltante, dropna - se eliminaron 2 registros con 2 NaN
# * Campo precio: encontre `$`, removerlo y luego cambiar el dtype a float64 - Ok
# * Campo fecha: ajustar a dtype datetime - Ok

# %%
# Eliminamos registros duplicados
# atributos a evaluar, keep, ignore_index, inplace
df_ventas.drop_duplicates(inplace=True, ignore_index=True)

# %%
# Validamos que no haya duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Eliminamos registros con datos nulos
df_ventas.dropna(inplace=True)

# %%
# Validamos que no haya nulos
# df_ventas.isnull().sum()
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 164.0+ KB

# %%
# Eliminamos el caracter especial $ de precio
# Normalización: usar replace()
# De ser necesario, podemos usar el atributo regex=True
df_ventas["precio"] = df_ventas["precio"].str.strip().str.replace("$", "")

# %%
# Validamos que precio no contenga $
df_ventas["precio"].sample(3)
# Out:
# 626     89.27
# 2357    61.18
# 253     59.33
# Name: precio, dtype: object

# %%
# Convertimos precio de str a float
# Podemos usar pd.to_numeric o astype o incluso combinarlos
df_ventas["precio"] = df_ventas["precio"].astype(float)

# %%
# Convertir el dtype de cantidad, de float64 a int64
df_ventas["cantidad"]= df_ventas["cantidad"].astype(int)

# %%
# Validar la conversion a int
df_ventas["cantidad"].dtypes
# Out:
# dtype('int64')

# %%
# Validamos campos numericos
df_ventas[["precio","cantidad"]].sample(3)
# Out:
#       precio  cantidad
# 46    116.04        11
# 1467   87.99         1
# 904   124.37         8

# %%
# Convertir el campo fecha_venta a dtype datetime
# pd.to_datetime(df_ventas["fecha_venta"], format="%d/%m/%Y")
# pd.to_datetime(df_ventas["fecha_venta"], dayfirst=True)
df_ventas['fecha_venta'] = pd.to_datetime(df_ventas['fecha_venta'], format="%d/%m/%Y")

# %%
# Validar la conversion de fecha
df_ventas['fecha_venta'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Renombrar ventas["precio"] a ventas["precio_unit"]  porque me resulta confuso
df_ventas.rename(columns={"precio": "precio_unit"}, inplace=True)

# %%
# Validar cambios
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio_unit  2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 164.0+ KB

# %%
# Hacemos una copia del DF ventas y guardamos a disco como csv
df_ventas_final = df_ventas.copy()

#df_ventas_final.to_csv("df_ventas_final.csv", index=False)

# %%
df_ventas_final.head()
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02
# 1       811    Lámpara de mesa       105.10         5  2024-01-02
# 2      1156           Secadora        97.96         3  2024-01-02
# 3      1372           Heladera       114.35         8  2024-01-02
# 4      1546           Secadora       106.21         4  2024-01-02
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos

# %% [markdown]
# VENTAS
# El df_ventas_final contiene 2998 registros

# %% [markdown]
# .
#
#
# ================================================================================

# %% [markdown]
# ### Dataframe marketing

# %% [markdown]
# ACCIONES
#
# Convertir el campo fecha_inicio a dtype = datetime
# Convertir el campo fecha_fin    a dtype = datetime

# %%
# Convertir el campo fecha_inicio a dtype datetime
df_marketing['fecha_inicio'] = pd.to_datetime(df_marketing['fecha_inicio'], format="%d/%m/%Y")

# %%
# Convertir el campo fecha_fin a dtype datetime
df_marketing['fecha_fin'] = pd.to_datetime(df_marketing['fecha_fin'], format="%d/%m/%Y")

# %%
# Validamos los cambios
df_marketing[["fecha_inicio","fecha_fin"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fecha_inicio  90 non-null     datetime64[ns]
#  1   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 1.5 KB

# %%
# Hacemos una copia del df_marketing
df_marketing_final = df_marketing.copy()

# Guardamos la copia a disco
df_marketing_final.to_csv('df_marketing_final.csv', index=False)

df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 4.3+ KB

# %%
df_marketing.head(9)
# Out:
#    id_campanha          producto  canal  costo fecha_inicio  fecha_fin
# 0           74   Adorno de pared     TV   4.81   2024-03-20 2024-05-03
# 1           12            Tablet   RRSS   3.40   2024-03-26 2024-05-13
# 2           32   Lámpara de mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21        Smartphone   RRSS   6.37   2024-03-29 2024-05-16
# 4           58          Alfombra  Email   4.25   2024-03-31 2024-05-05
# 5           85        SmartWatch     TV   5.07   2024-04-01 2024-05-05
# 6           36  Plancha de vapor  Email   5.41   2024-04-02 2024-06-01
# 7           57          Batidora  Email   4.48   2024-04-10 2024-06-08
# 8           44   Adorno de pared  Email   5.08   2024-04-13 2024-05-10

# %% [markdown]
#
#
# ### Dataframe clientes

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
df_clientes.head()
# Out:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahia Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65

# %%
# Hacemos una copia del df_clientes
df_clientes_final = df_clientes.copy()

# Guardamos la copia a disco
df_clientes_final.to_csv('df_clientes_final.csv', index=False)

# %% [markdown]
# .
#
# # **Transformación de datos**
# Actividad 2 - Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.

# %%
df_ventas_final.head(2)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta   categoria
# 0       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración

# %%
# Transformación:
# Calculamos el valor de cada venta = precio_unit * cantidad

# Agregamos una nueva columna  valor_venta = monto
df_ventas_final["valor_venta"] = df_ventas_final["precio_unit"] * df_ventas["cantidad"]

# %%
# Visualizamos
df_ventas_final.head(2)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
#
#    valor_venta
# 0        349.7
# 1        525.5

# %%
# Agregación:
# Agrupar valor_venta por producto
# Sumamos las ventas dentro de cada grupo
tabla_ventas = (df_ventas_final.groupby("producto", as_index=False)["valor_venta"].sum())
tabla_ventas.head()
# Out:
#           producto  valor_venta
# 0  Adorno de pared     48093.49
# 1         Alfombra     44773.06
# 2       Aspiradora     50085.86
# 3      Auriculares     74175.58
# 4         Batidora     50979.20

# %%
# Usemos describe para analizar algunos valores del dataframe resultante
tabla_ventas.describe()
# Out:
#         valor_venta
# count     30.000000
# mean   48903.117333
# std    13265.561715
# min    11128.800000
# 25%    45601.920000
# 50%    48140.245000
# 75%    51092.960000
# max    82276.380000

# %%
# Agregamos un plot para visualizar graficamente la distribución
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(tabla_ventas["valor_venta"], bins=30, kde=True, edgecolor="black")
plt.title("Distribución de Valor de Venta con Curva de Densidad")
plt.xlabel("Valor de venta")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Alto Rendimiento
# Los productos de alto rendimiento son aquellos que maximizan su utilidad, rentabilidad o eficiencia (se tomará quartil 75 )

# %%
# Calcular el percentil 75 (umbral de alto rendimiento)
umbral_ventas = tabla_ventas["valor_venta"].quantile(0.75)
umbral_ventas
# Out:
# np.float64(51092.96)

# %%
# Identificar productos que superan el umbral
# productos_top = tabla_ventas.query("valor_venta >= @umbral")
productos_top = tabla_ventas[tabla_ventas["valor_venta"] >= umbral_ventas]
productos_top
# Out:
#              producto  valor_venta
# 3         Auriculares     74175.58
# 5            Cafetera     59607.31
# 9   Cuadro decorativo     54297.60
# 16  Jarrón decorativo     51130.88
# 19    Lámpara de mesa     82276.38
# 20         Microondas     72562.89
# 25           Secadora     52115.45
# 27         Smartphone     54132.44

# %% [markdown]
# ## Agregación
# Actividad 3 - Resumir las ventas por categoría de producto y analizar los ingresos generados.

# %%
df_ventas_final.columns
# Out:
# Index(['id_venta', 'producto', 'precio_unit', 'cantidad', 'fecha_venta',
#        'categoria', 'valor_venta'],
#       dtype='object')

# %%
# Agrupamos por categoria y agregamos el total valor_venta por categoria
# (solo son 3 categorías )
ventas_categoria = df_ventas_final.groupby("categoria", as_index=False)["valor_venta"].sum()
ventas_categoria.head()
# Out:
#            categoria  valor_venta
# 0         Decoración    479216.09
# 1  Electrodomésticos    505299.63
# 2        Electrónica    482577.80

# %%
# Ordenar y mostrar los resultados
ventas_categoria.sort_values(by="valor_venta", ascending=False, inplace=True)
ventas_categoria
# Out:
#            categoria  valor_venta
# 1  Electrodomésticos    505299.63
# 2        Electrónica    482577.80
# 0         Decoración    479216.09

# %% [markdown]
# .
#
#
# ## Integración de datos
# Actividad 4 - Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %%
df_ventas_final.head(2)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
#
#    valor_venta
# 0        349.7
# 1        525.5

# %%
df_ventas_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio_unit  2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
#  6   valor_venta  2998 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 187.4+ KB

# %%
# renombrar costo => costo_mrkt y ojo con las cantidades !!!
# df_marketing.info()
df_marketing.rename(columns={"costo": "costo_mrkt"}, inplace=True)

df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo_mrkt fecha_inicio  fecha_fin
# 0           74  Adorno de pared     TV        4.81   2024-03-20 2024-05-03
# 1           12           Tablet   RRSS        3.40   2024-03-26 2024-05-13
# 2           32  Lámpara de mesa  Email        5.54   2024-03-28 2024-04-20
# 3           21       Smartphone   RRSS        6.37   2024-03-29 2024-05-16
# 4           58         Alfombra  Email        4.25   2024-03-31 2024-05-05

# %%
# Vemos la cantidad de productos unicos en ventas
df_ventas_final["producto"].nunique()
# Out:
# 30

# %%
# Vemos la cantidad de productos unicos en marketing
df_marketing["producto"].nunique()
# Out:
# 30

# %%
# Listamos los registros de ventas ordenados por producto, forma ascendente
df_ventas_final.sort_values(by="producto", ascending=True )
# Out:
#       id_venta                producto  precio_unit  cantidad fecha_venta  \
# 1478       410         Adorno de pared       109.64         3  2024-06-21
# 2428       620         Adorno de pared        92.16         4  2024-10-21
# 699        780         Adorno de pared        79.13         7  2024-03-21
# 257         50         Adorno de pared        83.10         5  2024-01-31
# 112        260         Adorno de pared       101.48         9  2024-01-15
# 1151       460         Adorno de pared        93.62         6  2024-05-11
# 2412       440         Adorno de pared       113.49         2  2024-10-17
# 693        950         Adorno de pared       116.42         6  2024-03-20
# 2774       640         Adorno de pared       110.44         7  2024-12-02
# 1128      1000         Adorno de pared        74.64        11  2024-05-08
# 864        600         Adorno de pared        66.00         4  2024-04-10
# 101         20         Adorno de pared        90.21         2  2024-01-14
# 1536        10         Adorno de pared        44.65        10  2024-06-29
# 2399       990         Adorno de pared        76.72         3  2024-10-15
# 278        380         Adorno de pared        45.84        10  2024-02-02
# 2397       520         Adorno de pared        85.98         5  2024-10-15
# 1109       550         Adorno de pared        98.99         8  2024-05-06
# 2818       130         Adorno de pared        68.70         3  2024-12-08
# 2353        60         Adorno de pared        32.58         9  2024-10-10
# 2342       670         Adorno de pared        55.21         7  2024-10-08
# 1579       360         Adorno de pared        67.02         9  2024-07-04
# 1100       650         Adorno de pared        43.11         4  2024-05-05
# 2293       590         Adorno de pared        30.18         8  2024-10-01
# 2280       500         Adorno de pared       110.88         4  2024-09-30
# 72         830         Adorno de pared        67.23        10  2024-01-10
# 325        770         Adorno de pared       103.74         5  2024-02-07
# 1625       790         Adorno de pared        89.14         5  2024-07-10
# 334        850         Adorno de pared       112.03         9  2024-02-08
# 2429       680         Adorno de pared        76.66         3  2024-10-21
# 1081       220         Adorno de pared        55.36         9  2024-05-03
# 1484       330         Adorno de pared        60.02         6  2024-06-22
# 2464       690         Adorno de pared       103.95         8  2024-10-26
# 2607       880         Adorno de pared       105.74        10  2024-11-12
# 2604       420         Adorno de pared        65.00         4  2024-11-12
# 801        570         Adorno de pared        64.18         7  2024-04-03
# 1311       110         Adorno de pared        33.01         1  2024-05-29
# 783        390         Adorno de pared        87.52         8  2024-04-01
# 2647        70         Adorno de pared       105.42        12  2024-11-18
# 1334       530         Adorno de pared        82.65         5  2024-06-01
# 1339       160         Adorno de pared        33.27        12  2024-06-02
# 153         30         Adorno de pared        76.92         6  2024-01-19
# 187         80         Adorno de pared        51.56         5  2024-01-23
# 1374       740         Adorno de pared       103.19         9  2024-06-06
# 813        340         Adorno de pared        49.30         2  2024-04-04
# 814        400         Adorno de pared        33.10         1  2024-04-04
# 1376       890         Adorno de pared        91.85         6  2024-06-06
# 754        730         Adorno de pared       103.90         8  2024-03-28
# 1392       910         Adorno de pared        47.55         3  2024-06-08
# 143        430         Adorno de pared        81.76         5  2024-01-18
# 2538       610         Adorno de pared        27.89         8  2024-11-04
# 1411       810         Adorno de pared       105.57         7  2024-06-11
# 827        300         Adorno de pared        67.75         9  2024-04-06
# 2504       190         Adorno de pared        36.08        10  2024-10-30
# 1214       920         Adorno de pared        39.60         8  2024-05-18
# 1430       350         Adorno de pared        79.48        12  2024-06-13
# 1437        90         Adorno de pared       119.30         2  2024-06-14
# 1193       660         Adorno de pared        71.13         9  2024-05-16
# 223        310         Adorno de pared       103.79         2  2024-01-27
# 722        210         Adorno de pared        71.67         4  2024-03-24
# 710        270         Adorno de pared        96.59         6  2024-03-22
# 627        820         Adorno de pared        36.55         3  2024-03-14
# 306         40         Adorno de pared       100.32        10  2024-02-05
# 2921       800         Adorno de pared       116.74         3  2024-12-21
# 576        470         Adorno de pared        34.68         5  2024-03-09
# 38         560         Adorno de pared        57.62         6  2024-01-07
# 2883       370         Adorno de pared        93.19         8  2024-12-16
# 1800       860         Adorno de pared        49.28         9  2024-08-01
# 543        140         Adorno de pared        44.91         1  2024-03-05
# 437        720         Adorno de pared        90.05         1  2024-02-21
# 2051       280         Adorno de pared        29.81         9  2024-09-01
# 533        760         Adorno de pared        77.65         1  2024-03-03
# 2018       480         Adorno de pared       117.68        10  2024-08-28
# 997        320         Adorno de pared        37.38         6  2024-04-25
# 1984       450         Adorno de pared        79.85         6  2024-08-24
# 1758       290         Adorno de pared       100.50        12  2024-07-27
# 17         630         Adorno de pared        71.99         9  2024-01-04
# 2951       120         Adorno de pared        64.26         6  2024-12-25
# 1974       230         Adorno de pared        88.01         1  2024-08-23
# 468        930         Adorno de pared        75.13         6  2024-02-24
# 1964       490         Adorno de pared       108.27         8  2024-08-22
# 1953       940         Adorno de pared        67.34         4  2024-08-21
# 1944       710         Adorno de pared        78.73        11  2024-08-20
# 1941       540         Adorno de pared       110.50         3  2024-08-20
# 1939       180         Adorno de pared       118.38        11  2024-08-20
# 2982       240         Adorno de pared        81.02         7  2024-12-29
# 499        150         Adorno de pared        27.92         5  2024-02-28
# 1917       170         Adorno de pared        36.04        11  2024-08-16
# 1887       700         Adorno de pared        41.59         1  2024-08-12
# 2197       900         Adorno de pared        78.06         9  2024-09-19
# 1303       510         Adorno de pared        79.02         5  2024-05-28
# 2234       750         Adorno de pared       108.77         2  2024-09-25
# 2228       960         Adorno de pared        56.56         8  2024-09-24
# 2227       580         Adorno de pared        41.81        12  2024-09-24
# 349        840         Adorno de pared        91.48         9  2024-02-10
# 2886       980         Adorno de pared        75.85         6  2024-12-16
# 2213       250         Adorno de pared       104.58         7  2024-09-22
# 1067       100         Adorno de pared       112.16         8  2024-05-02
# 1670       200         Adorno de pared       110.40         5  2024-07-16
# 1722       870         Adorno de pared        85.11         4  2024-07-22
# 368        970         Adorno de pared        37.50         3  2024-02-12
# 359        205                Alfombra       108.67         4  2024-02-11
# 1873       295                Alfombra        38.83        10  2024-08-10
# 1601       965                Alfombra        75.30         4  2024-07-07
# 2000       675                Alfombra        64.25        10  2024-08-26
# 1695       155                Alfombra        79.26        10  2024-07-19
# 2527         5                Alfombra        70.10         4  2024-11-02
# 2042       325                Alfombra        84.56         3  2024-08-31
# 204         85                Alfombra        71.14         2  2024-01-25
# 733        595                Alfombra        83.25         1  2024-03-25
# 2529       605                Alfombra       120.49         6  2024-11-02
# 2283       705                Alfombra        49.89         3  2024-09-30
# 2281       565                Alfombra        55.34         2  2024-09-30
# 2279       415                Alfombra        63.40         5  2024-09-30
# 291        695                Alfombra        51.29         2  2024-02-03
# 1976       955                Alfombra        93.23         7  2024-08-23
# 2558       825                Alfombra        34.70         1  2024-11-07
# 1597       215                Alfombra        73.11         3  2024-07-07
# 2251       445                Alfombra        70.36        12  2024-09-27
# 2278       385                Alfombra        86.29         3  2024-09-30
# 326        895                Alfombra       102.72         2  2024-02-07
# 333        745                Alfombra        50.02        12  2024-02-08
# 1326       995                Alfombra       109.03        10  2024-05-31
# 1937       115                Alfombra        54.17         6  2024-08-20
# 2595       545                Alfombra        43.63         1  2024-11-11
# 1644        55                Alfombra        53.54        12  2024-07-13
# 1659       105                Alfombra        43.53         9  2024-07-15
# 498         95                Alfombra        87.85         2  2024-02-28
# 789         45                Alfombra        72.91         1  2024-04-02
# 2554       875                Alfombra        36.34         5  2024-11-06
# 465        365                Alfombra        58.82         9  2024-02-24
# 534        985                Alfombra       118.35         3  2024-03-03
# 1463       625                Alfombra       124.91         3  2024-06-18
# 1562       795                Alfombra       124.05        10  2024-07-02
# 672        505                Alfombra        96.21        11  2024-03-18
# 2380       725                Alfombra       111.36        11  2024-10-12
# 1561       735                Alfombra        47.63         5  2024-07-02
# 600        615                Alfombra        65.09         5  2024-03-11
# 1555       585                Alfombra        72.74         3  2024-07-01
# 1537       125                Alfombra        92.80         2  2024-06-29
# 1773       845                Alfombra        46.70         3  2024-07-29
# 578        805                Alfombra        48.99         8  2024-03-09
# 577        685                Alfombra       102.81         9  2024-03-09
# 408        275                Alfombra        36.14         8  2024-02-18
# 692        855                Alfombra        48.79        11  2024-03-20
# 1572       865                Alfombra        80.74         6  2024-07-03
# 1515       815                Alfombra       124.88         7  2024-06-26
# 2411       355                Alfombra       124.48         4  2024-10-17
# 2136       935                Alfombra        97.17         5  2024-09-12
# 569        435                Alfombra        97.14         1  2024-03-08
# 2478       835                Alfombra        85.65         6  2024-10-27
# 2477       755                Alfombra        27.68         3  2024-10-27
# 2475        25                Alfombra        38.69         1  2024-10-27
# 1584       335                Alfombra        38.03         1  2024-07-05
# 2609       655                Alfombra       124.49        11  2024-11-13
# 711        645                Alfombra        36.17         1  2024-03-22
# 1456       485                Alfombra       113.90         2  2024-06-17
# 1820       525                Alfombra        29.53        12  2024-08-03
# 1809       535                Alfombra       115.82         1  2024-08-02
# 559        635                Alfombra        44.66         7  2024-03-07
# 2085       515                Alfombra        34.54        10  2024-09-06
# 1578       165                Alfombra       110.83         2  2024-07-04
# 2086       665                Alfombra        60.18         7  2024-09-06
# 698        195                Alfombra       115.12        12  2024-03-21
# 709         65                Alfombra        63.14         2  2024-03-22
# 345        135                Alfombra        78.47         1  2024-02-10
# 1951        35                Alfombra        65.80        11  2024-08-21
# 1271       465                Alfombra        76.75         2  2024-05-24
# 2694       785                Alfombra        97.30         5  2024-11-23
# 1223       405                Alfombra        33.36        10  2024-05-19
# 2713       225                Alfombra        28.53         6  2024-11-26
# 839        345                Alfombra        56.78         9  2024-04-07
# 2728       715                Alfombra        32.65         3  2024-11-27
# 2754       775                Alfombra       111.87         7  2024-11-30
# 1158       495                Alfombra        90.94        12  2024-05-12
# 2791       555                Alfombra        97.75         9  2024-12-04
# 2800       175                Alfombra       108.47         2  2024-12-05
# 2801       455                Alfombra        82.60        11  2024-12-05
# 1111       915                Alfombra        43.37        11  2024-05-06
# 2830       265                Alfombra        66.72        12  2024-12-10
# 69         315                Alfombra       122.07         9  2024-01-10
# 899        285                Alfombra       107.80         7  2024-04-14
# 1059       475                Alfombra       120.18         3  2024-05-01
# 910        185                Alfombra        45.21         6  2024-04-15
# 1051       975                Alfombra        28.96         5  2024-04-30
# 1049       255                Alfombra        68.38         7  2024-04-30
# 2903        75                Alfombra        65.48         5  2024-12-18
# 2914        15                Alfombra        47.77         6  2024-12-20
# 1020       375                Alfombra        70.93         8  2024-04-27
# 1008       765                Alfombra        72.71         1  2024-04-26
# 989        945                Alfombra        60.74        12  2024-04-24
# 942        925                Alfombra        52.55        11  2024-04-18
# 974        305                Alfombra        91.25         2  2024-04-22
# 948        905                Alfombra       112.82         9  2024-04-19
# 2991       235                Alfombra       112.51         6  2024-12-30
# 826        145                Alfombra        41.72         8  2024-04-06
# 1224       575                Alfombra       110.42        11  2024-05-19
# 1921       245                Alfombra        44.82        11  2024-08-17
# 2615       885                Alfombra        97.56         1  2024-11-14
# 157        395                Alfombra        33.48        12  2024-01-19
# 1253       425                Alfombra        45.68        10  2024-05-22
# 1394      1474              Aspiradora        91.09        11  2024-06-08
# 65        1584              Aspiradora        99.58         7  2024-01-09
# 2876      1834              Aspiradora        51.50         6  2024-12-15
# 1664      1494              Aspiradora        82.50         6  2024-07-15
# 1666      1604              Aspiradora        99.90         8  2024-07-15
# 2253      1674              Aspiradora        40.59         8  2024-09-27
# 351       1294              Aspiradora        26.11         9  2024-02-10
# 1675      1824              Aspiradora        44.78        12  2024-07-16
# 1690      1614              Aspiradora        56.92         7  2024-07-18
# 1692      1714              Aspiradora        75.51        12  2024-07-18
# 53        1734              Aspiradora        50.86         4  2024-01-08
# 915       1134              Aspiradora        69.06        11  2024-04-15
# 1707      1364              Aspiradora        68.72        11  2024-07-20
# 2899      1504              Aspiradora        42.52         2  2024-12-17
# 2270      1704              Aspiradora       111.82         9  2024-09-29
# 1083      1004              Aspiradora       107.00         8  2024-05-03
# 75        1464              Aspiradora        36.38         5  2024-01-10
# 917       1454              Aspiradora        51.46         4  2024-04-15
# 2389      1034              Aspiradora        44.82         2  2024-10-13
# 675       1384              Aspiradora        80.38         9  2024-03-18
# 1112      1304              Aspiradora        99.07         8  2024-05-06
# 2808      1194              Aspiradora        56.97         1  2024-12-06
# 2362      1724              Aspiradora        95.89         1  2024-10-10
# 2345      1204              Aspiradora        87.88         2  2024-10-08
# 2821      1264              Aspiradora       114.28         6  2024-12-08
# 300       1424              Aspiradora        69.31        10  2024-02-04
# 664       1164              Aspiradora       102.32         2  2024-03-17
# 82        1234              Aspiradora        36.89         7  2024-01-11
# 1103      1484              Aspiradora        79.74         6  2024-05-05
# 885       1394              Aspiradora        68.73         5  2024-04-12
# 314       1064              Aspiradora        65.00         9  2024-02-06
# 2289      1644              Aspiradora       123.36        11  2024-09-30
# 2848      1414              Aspiradora        85.23        10  2024-12-12
# 1632      1884              Aspiradora        94.69         4  2024-07-11
# 604       1934              Aspiradora        42.94         2  2024-03-11
# 178       1754              Aspiradora       104.86         8  2024-01-21
# 1727      1444              Aspiradora       118.58         2  2024-07-23
# 1869      1654              Aspiradora        83.90         1  2024-08-09
# 1988      1114              Aspiradora        86.38        10  2024-08-24
# 1987      1074              Aspiradora        31.76         8  2024-08-24
# 2948      1794              Aspiradora        61.80        12  2024-12-24
# 515       1984              Aspiradora        88.95        11  2024-02-29
# 12        1814              Aspiradora        70.91         2  2024-01-03
# 1895      1514              Aspiradora        82.69         3  2024-08-13
# 10        1374              Aspiradora        95.90         5  2024-01-03
# 1955      1124              Aspiradora        92.55         4  2024-08-21
# 2625      1564              Aspiradora        60.80         1  2024-11-15
# 949       1224              Aspiradora       110.58         4  2024-04-19
# 1901      1054              Aspiradora        86.59         2  2024-08-14
# 945       1914              Aspiradora        92.52         1  2024-04-18
# 2977      1274              Aspiradora       124.15         9  2024-12-28
# 1914      1894              Aspiradora        55.65         5  2024-08-15
# 2022      1994              Aspiradora       109.08         7  2024-08-28
# 1351      1664              Aspiradora        69.63        12  2024-06-02
# 1857      1284              Aspiradora        31.94         7  2024-08-07
# 1843      1174              Aspiradora        69.14         8  2024-08-05
# 2186      1044              Aspiradora        47.53         1  2024-09-17
# 44        1524              Aspiradora        65.55         8  2024-01-07
# 581       1844              Aspiradora        86.29        12  2024-03-09
# 1036      1964              Aspiradora        52.92        10  2024-04-28
# 404       1924              Aspiradora        38.10         9  2024-02-17
# 2916      1624              Aspiradora        28.64         9  2024-12-20
# 2129      1404              Aspiradora        76.10        11  2024-09-11
# 571       1434              Aspiradora        60.42        11  2024-03-08
# 2116      1954              Aspiradora        79.88         3  2024-09-09
# 1792      1944              Aspiradora        55.59         1  2024-07-31
# 2102      1184              Aspiradora        69.85         3  2024-09-08
# 2922      1594              Aspiradora        46.90         8  2024-12-21
# 1023      1804              Aspiradora        43.25         7  2024-04-27
# 1803      1854              Aspiradora       103.99         8  2024-08-01
# 927       1864              Aspiradora        54.94         3  2024-04-16
# 2056      1684              Aspiradora        58.65         2  2024-09-01
# 2794      1324              Aspiradora       106.89         5  2024-12-04
# 2653      1314              Aspiradora        86.12         6  2024-11-18
# 329       1554              Aspiradora       124.82         3  2024-02-07
# 1423      1154              Aspiradora        95.11         4  2024-06-12
# 2415      1534              Aspiradora        96.98         8  2024-10-18
# 833       1784              Aspiradora       115.24         3  2024-04-06
# 2418      1574              Aspiradora        92.59        10  2024-10-19
# 2490      1144              Aspiradora        98.46         7  2024-10-28
# 834       1974              Aspiradora        87.32         7  2024-04-06
# 726       1904              Aspiradora       102.92         5  2024-03-24
# 264       1254              Aspiradora        74.11        11  2024-01-31
# 1371      1334              Aspiradora        43.21         7  2024-06-05
# 226       1744              Aspiradora        28.79        12  2024-01-27
# 2482      1094              Aspiradora       115.50         8  2024-10-27
# 2719      1544              Aspiradora        87.56         8  2024-11-26
# 2748      1634              Aspiradora        94.20        12  2024-11-29
# 2444      1214              Aspiradora       121.66         3  2024-10-23
# 2466      1354              Aspiradora        55.17         4  2024-10-26
# 2455      1014              Aspiradora       106.17        12  2024-10-25
# 1491      1084              Aspiradora       119.83         7  2024-06-23
# 856       1344              Aspiradora        34.10         3  2024-04-09
# 1468      1244              Aspiradora       103.91         4  2024-06-19
# 1236      1104              Aspiradora        76.20         5  2024-05-20
# 1238      1694              Aspiradora        79.23         9  2024-05-20
# 745       1874              Aspiradora        78.77         1  2024-03-26
# 273       1764              Aspiradora       112.38        10  2024-02-01
# 1246      1024              Aspiradora        35.94        11  2024-05-21
# 2677      1774              Aspiradora       120.80         3  2024-11-20
# 399       2825             Auriculares        39.92         4  2024-02-16
# 2153      2805             Auriculares        32.81         7  2024-09-13
# 2152      2795             Auriculares        71.49         5  2024-09-13
# 2644      2074             Auriculares        70.55         1  2024-11-17
# 1182      2635             Auriculares        96.21        11  2024-05-14
# 406       2255             Auriculares        72.37         8  2024-02-17
# 952       2095             Auriculares       117.60         3  2024-04-19
# 1731      2524             Auriculares        74.77         7  2024-07-23
# 46        2174             Auriculares       116.04        11  2024-01-07
# 1026      2465             Auriculares        93.52         3  2024-04-27
# 1785      2475             Auriculares        78.96         1  2024-07-30
# 228       2165             Auriculares        47.24         9  2024-01-27
# 2742      2675             Auriculares        75.36         6  2024-11-28
# 953       2375             Auriculares        73.70        10  2024-04-19
# 1030      2645             Auriculares       122.64        10  2024-04-27
# 407       2345             Auriculares        61.61         4  2024-02-17
# 398       2595             Auriculares        81.96         2  2024-02-16
# 2967      2605             Auriculares        41.66         3  2024-12-26
# 598       2944             Auriculares        55.17         4  2024-03-10
# 761       2585             Auriculares        47.12        12  2024-03-29
# 2473      2285             Auriculares        57.38         1  2024-10-26
# 1761      2045             Auriculares        94.17         5  2024-07-27
# 584       2684             Auriculares        79.29         6  2024-03-09
# 2166      2755             Auriculares       118.00         8  2024-09-14
# 585       2694             Auriculares        51.71         3  2024-03-09
# 2171      2505             Auriculares        71.47         7  2024-09-15
# 1174      2875             Auriculares        55.41        10  2024-05-13
# 2619      2374             Auriculares        55.05        12  2024-11-14
# 2192      2485             Auriculares        95.27         8  2024-09-17
# 385       2154             Auriculares        45.97        12  2024-02-14
# 1114      2264             Auriculares        58.19         6  2024-05-06
# 397       2304             Auriculares        44.56         8  2024-02-16
# 2108      2205             Auriculares        70.24         6  2024-09-08
# 987       2993             Auriculares        38.79         7  2024-04-23
# 1415      2235             Auriculares        74.81        12  2024-06-11
# 132       2935             Auriculares        80.29         2  2024-01-16
# 2503      2774             Auriculares        37.77         7  2024-10-29
# 2942      2355             Auriculares       119.48         8  2024-12-23
# 2946      2905             Auriculares        40.58         2  2024-12-23
# 1970      2215             Auriculares       124.96         8  2024-08-22
# 1883      2665             Auriculares       120.36         2  2024-08-11
# 148       2244             Auriculares        63.67         5  2024-01-18
# 213       2735             Auriculares        93.37        10  2024-01-25
# 508       2695             Auriculares       104.59         9  2024-02-28
# 1414      2065             Auriculares       108.07        10  2024-06-11
# 1420      2955             Auriculares       106.03         7  2024-06-11
# 1982      2535             Auriculares        95.54        11  2024-08-23
# 994       2565             Auriculares        49.70         3  2024-04-24
# 2603      2814             Auriculares        89.91         9  2024-11-11
# 788       2865             Auriculares        89.29         2  2024-04-01
# 1864      2815             Auriculares       117.07        12  2024-08-08
# 2695      2194             Auriculares       102.22        11  2024-11-23
# 2040      2655             Auriculares        56.28         9  2024-08-30
# 2935      2845             Auriculares        34.64        10  2024-12-22
# 2090      2405             Auriculares       109.22         8  2024-09-06
# 35        2885             Auriculares       100.40         6  2024-01-06
# 1949      2575             Auriculares        39.02         9  2024-08-20
# 1794      2225             Auriculares        66.16         7  2024-07-31
# 2634      2025             Auriculares        42.93         2  2024-11-16
# 221       2305             Auriculares        31.03         9  2024-01-26
# 1015      2504             Auriculares        76.65        10  2024-04-26
# 1465      2765             Auriculares        63.93         8  2024-06-18
# 2070      2195             Auriculares       122.51        11  2024-09-03
# 478       2175             Auriculares       117.03         6  2024-02-25
# 2057      2015             Auriculares        87.91         5  2024-09-01
# 1405      2105             Auriculares        46.74        12  2024-06-09
# 535       2975             Auriculares        55.20        10  2024-03-03
# 931       2615             Auriculares        46.72        11  2024-04-16
# 932       2715             Auriculares       100.58         7  2024-04-16
# 1263      2895             Auriculares        53.91         4  2024-05-22
# 1717      2314             Auriculares        68.94         9  2024-07-21
# 28        2155             Auriculares        84.80        10  2024-01-05
# 276       2474             Auriculares       123.41         8  2024-02-01
# 371       2334             Auriculares        57.41         4  2024-02-12
# 2311      2725             Auriculares       107.61         1  2024-10-03
# 2306      2915             Auriculares        33.81        11  2024-10-02
# 2299      2295             Auriculares        56.21         2  2024-10-01
# 2416      2614             Auriculares        47.88         4  2024-10-18
# 2843      2144             Auriculares       100.70        11  2024-12-11
# 851       2365             Auriculares        92.91        11  2024-04-08
# 1089      2985             Auriculares        58.92         3  2024-05-03
# 647       2835             Auriculares        42.50         7  2024-03-15
# 1590      2265             Auriculares        82.56        12  2024-07-05
# 1155      2364             Auriculares        94.13        10  2024-05-11
# 1087      2435             Auriculares        39.55         3  2024-05-03
# 2852      2734             Auriculares        95.05         5  2024-12-12
# 372       2714             Auriculares        74.70        10  2024-02-12
# 645       2554             Auriculares       100.07        11  2024-03-15
# 2863      2145             Auriculares        79.28         9  2024-12-14
# 2276      2925             Auriculares        26.21         4  2024-09-29
# 1622      2604             Auriculares       106.41         3  2024-07-09
# 330       2584             Auriculares        42.67         6  2024-02-07
# 256       2945             Auriculares       115.20         1  2024-01-30
# 2565      2335             Auriculares       108.76         8  2024-11-07
# 109       2685             Auriculares        27.36        10  2024-01-14
# 854       2705             Auriculares        87.29         2  2024-04-08
# 1557      2525             Auriculares        78.62        11  2024-07-01
# 2660      2274             Auriculares       114.43         1  2024-11-18
# 1558      2744             Auriculares        70.61         1  2024-07-01
# 677       2454             Auriculares       101.08        10  2024-03-18
# 676       2035             Auriculares        78.28         6  2024-03-18
# 2390      2075             Auriculares        75.39         7  2024-10-13
# 284       2115             Auriculares        26.00         9  2024-02-02
# 1359      2055             Auriculares       104.83         9  2024-06-03
# 1106      2445             Auriculares        93.33         6  2024-05-05
# 1122      2415             Auriculares        35.87         5  2024-05-07
# 874       2785             Auriculares       122.80         3  2024-04-10
# 268       2752             Auriculares       119.77         5  2024-01-31
# 667       2444             Auriculares        70.16        11  2024-03-17
# 267       2185             Auriculares        35.74        11  2024-01-31
# 86        2325             Auriculares       117.43        11  2024-01-11
# 1142      2974             Auriculares        79.28         2  2024-05-09
# 2338      2515             Auriculares        99.53         1  2024-10-07
# 303       2315             Auriculares       109.07         4  2024-02-04
# 767       2034             Auriculares       120.46         8  2024-03-30
# 2758      2385             Auriculares        92.15         4  2024-11-30
# 1086      2404             Auriculares       102.65         4  2024-05-03
# 1667      2625             Auriculares        77.33         6  2024-07-15
# 845       2085             Auriculares       122.56         6  2024-04-07
# 717       2634             Auriculares       124.63        10  2024-03-22
# 907       2275             Auriculares        32.00         1  2024-04-14
# 1700      2954             Auriculares        86.93         7  2024-07-19
# 2449      2914             Auriculares        26.34         5  2024-10-23
# 2889      2135             Auriculares        34.52         4  2024-12-16
# 1472      2455             Auriculares        91.06         3  2024-06-19
# 2248      2994             Auriculares        94.36         9  2024-09-26
# 1923      2395             Auriculares        74.82        11  2024-08-17
# 244       2245             Auriculares        53.45         8  2024-01-29
# 1693      2834             Auriculares        65.34         4  2024-07-18
# 1694      2855             Auriculares        57.89         2  2024-07-18
# 1698      2555             Auriculares        37.08         1  2024-07-19
# 1330      2745             Auriculares        70.62         7  2024-05-31
# 1317      2125             Auriculares        33.47         2  2024-05-29
# 824       2545             Auriculares        32.81        11  2024-04-05
# 2447      2094             Auriculares       118.97         5  2024-10-23
# 342       2294             Auriculares        54.54         9  2024-02-09
# 1711      2484             Auriculares        76.32        10  2024-07-20
# 1709      2184             Auriculares        31.39         2  2024-07-20
# 1079      2775             Auriculares       104.06        11  2024-05-02
# 252       2005             Auriculares        56.56         4  2024-01-30
# 2450      2965             Auriculares        70.70        11  2024-10-23
# 1651      2425             Auriculares        99.13         7  2024-07-13
# 1657      2495             Auriculares       107.82         4  2024-07-14
# 1747      1279                Batidora        42.67        10  2024-07-25
# 1723      1249                Batidora        79.15        10  2024-07-22
# 1395      1729                Batidora        72.01         9  2024-06-08
# 1894      1299                Batidora        93.10         3  2024-08-13
# 1316      1719                Batidora       106.81        10  2024-05-29
# 877       1109                Batidora       123.83        12  2024-04-11
# 1467      1069                Batidora        87.99         1  2024-06-19
# 1526      1549                Batidora       106.44         6  2024-06-27
# 593       1219                Batidora        49.37         9  2024-03-10
# 858       1979                Batidora        88.23        11  2024-04-09
# 1708      1909                Batidora       124.45         5  2024-07-20
# 506       1839                Batidora        63.50         3  2024-02-28
# 504       1669                Batidora        69.74         8  2024-02-28
# 872       1919                Batidora        38.51         9  2024-04-10
# 1403      1179                Batidora       123.86         3  2024-06-09
# 1896      1589                Batidora        36.18         7  2024-08-13
# 1565      1799                Batidora        29.22         2  2024-07-02
# 924       1629                Batidora       108.94         6  2024-04-16
# 1879      1289                Batidora        76.71         7  2024-08-11
# 513       1569                Batidora       122.02        12  2024-02-29
# 1187      1739                Batidora        30.74        10  2024-05-15
# 1084      1439                Batidora        71.74         9  2024-05-03
# 570       1229                Batidora        29.86         4  2024-03-08
# 1085      1819                Batidora        87.56         9  2024-05-03
# 796       1889                Batidora       121.14         3  2024-04-02
# 1247      1479                Batidora       121.07         1  2024-05-21
# 1336      1929                Batidora        92.87        10  2024-06-01
# 1833      1019                Batidora        73.65        10  2024-08-04
# 1160      1269                Batidora        46.78         5  2024-05-12
# 573       1879                Batidora        65.59         9  2024-03-08
# 1162      1789                Batidora        45.45        12  2024-05-12
# 1369      1199                Batidora        58.03        10  2024-06-05
# 1034      1329                Batidora        55.84         7  2024-04-28
# 1009      1119                Batidora        59.86         3  2024-04-26
# 652       1099                Batidora        39.73        11  2024-03-16
# 1850      1419                Batidora        60.56         1  2024-08-06
# 1075      1969                Batidora        72.90         1  2024-05-02
# 579       1369                Batidora        48.80        11  2024-03-09
# 935       1009                Batidora       119.03         8  2024-04-17
# 526       1089                Batidora        61.72         8  2024-03-02
# 1870      1809                Batidora        42.42         4  2024-08-09
# 1874      1259                Batidora        71.83        12  2024-08-10
# 519       1189                Batidora        82.18         6  2024-03-01
# 1633      1899                Batidora        83.64         1  2024-07-11
# 1760      1829                Batidora        96.16         1  2024-07-27
# 665       1209                Batidora       111.44         3  2024-03-17
# 592       1169                Batidora        85.59         5  2024-03-10
# 950       1459                Batidora        66.73         8  2024-04-19
# 235       1999                Batidora       103.27         3  2024-01-28
# 2666      1159                Batidora       111.36         7  2024-11-19
# 2161      1689                Batidora        96.25         7  2024-09-14
# 293       1499                Batidora        77.53         4  2024-02-03
# 2674      1079                Batidora        53.18         2  2024-11-20
# 2689      1309                Batidora        68.82         5  2024-11-22
# 2690      1759                Batidora        82.06         2  2024-11-22
# 2756      1769                Batidora        95.64         2  2024-11-30
# 2627      1749                Batidora       107.07         9  2024-11-15
# 2103      1399                Batidora       110.91         8  2024-09-08
# 2075      1149                Batidora        34.05         8  2024-09-05
# 106       1599                Batidora        96.78        12  2024-01-14
# 428       1409                Batidora        79.10         4  2024-02-20
# 2787      1379                Batidora       103.94         5  2024-12-03
# 2802      1469                Batidora       100.43         8  2024-12-05
# 83        1319                Batidora        79.98        12  2024-01-11
# 2847      1029                Batidora        36.33         5  2024-12-12
# 2770      1849                Batidora        30.17         9  2024-12-01
# 166       1489                Batidora        95.59         3  2024-01-20
# 2198      1129                Batidora        71.39         3  2024-09-19
# 2199      1389                Batidora        71.36         9  2024-09-19
# 2361      1239                Batidora        94.29         2  2024-10-10
# 2322      1779                Batidora       122.12         4  2024-10-05
# 2314      1709                Batidora        89.72        10  2024-10-04
# 2421      1859                Batidora        81.35         8  2024-10-19
# 2467      1449                Batidora        73.18        12  2024-10-26
# 2483      1349                Batidora       100.89         5  2024-10-27
# 2484      1519                Batidora       101.17        11  2024-10-27
# 2492      1659                Batidora       101.49         6  2024-10-28
# 2269      1679                Batidora        49.23        12  2024-09-29
# 337       1529                Batidora        79.14        10  2024-02-08
# 2534      1559                Batidora        59.48         4  2024-11-02
# 2536      1049                Batidora        64.32         8  2024-11-03
# 2589      1619                Batidora        96.56         3  2024-11-10
# 2236      1359                Batidora       121.44        11  2024-09-25
# 2599      1509                Batidora        55.25        10  2024-11-11
# 2216      1949                Batidora        33.51         5  2024-09-22
# 2201      1699                Batidora        48.45         5  2024-09-19
# 2850      1959                Batidora        83.12         2  2024-12-12
# 2862      1579                Batidora        68.09         5  2024-12-14
# 2159      1539                Batidora        77.73         4  2024-09-14
# 1945      1609                Batidora        79.45         8  2024-08-20
# 2888      1989                Batidora       124.17         7  2024-12-16
# 2971      1429                Batidora       103.49         8  2024-12-27
# 2915      1059                Batidora        55.79         9  2024-12-20
# 2986      1139                Batidora        28.94        10  2024-12-29
# 2010      1869                Batidora        46.90         7  2024-08-27
# 1979      1939                Batidora        74.11        10  2024-08-23
# 1929      1339                Batidora       105.41         1  2024-08-18
# 1977      1039                Batidora        55.47         1  2024-08-23
# 67        1649                Batidora        39.26        11  2024-01-09
# 2900      1639                Batidora        89.35        11  2024-12-17
# 477       1852                Cafetera        76.00         7  2024-02-25
# 1380      1888                Cafetera        44.54         4  2024-06-06
# 1946      1688                Cafetera       112.14         3  2024-08-20
# 743       1648                Cafetera        63.49         7  2024-03-26
# 191       1592                Cafetera        86.79         3  2024-01-23
# 1363      1518                Cafetera        46.70         2  2024-06-04
# 2572      1098                Cafetera        45.95         7  2024-11-08
# 185       1808                Cafetera        45.98         3  2024-01-22
# 206       1378                Cafetera        96.94         4  2024-01-25
# 2573      1348                Cafetera       111.70        10  2024-11-08
# 1328      1418                Cafetera        91.72        12  2024-05-31
# 2941      1728                Cafetera        75.14        11  2024-12-23
# 2265      1268                Cafetera        94.35        12  2024-09-29
# 2934      1968                Cafetera        69.28         2  2024-12-22
# 780       1948                Cafetera       116.78         6  2024-03-31
# 179       1882                Cafetera        51.16        12  2024-01-21
# 2229      1298                Cafetera        60.68         6  2024-09-24
# 610       1248                Cafetera        30.70         5  2024-03-12
# 1315      1478                Cafetera       121.90         2  2024-05-29
# 470       1558                Cafetera        68.89         6  2024-02-24
# 469       1182                Cafetera       113.84         2  2024-02-24
# 2608      1908                Cafetera        55.91         3  2024-11-12
# 2208      1538                Cafetera       120.80         7  2024-09-21
# 2245      1228                Cafetera       115.89         4  2024-09-26
# 2266      1408                Cafetera        56.98        11  2024-09-29
# 893       1758                Cafetera       118.03         5  2024-04-13
# 1655      1078                Cafetera        38.47         1  2024-07-14
# 1566      1998                Cafetera       101.11         7  2024-07-02
# 494       1988                Cafetera        49.32         3  2024-02-27
# 272       1102                Cafetera       108.33         2  2024-02-01
# 2401      1308                Cafetera        96.89         7  2024-10-15
# 2335      1738                Cafetera        40.25         3  2024-10-07
# 1573      1058                Cafetera        52.48         6  2024-07-03
# 1575      1958                Cafetera       115.80        12  2024-07-03
# 1531      1668                Cafetera       111.39        12  2024-06-28
# 1530      1448                Cafetera        44.00         4  2024-06-28
# 2313      1358                Cafetera        95.67        12  2024-10-04
# 266       1898                Cafetera        63.54         9  2024-01-31
# 316       1848                Cafetera       123.27         4  2024-02-06
# 1501      1858                Cafetera        30.27         4  2024-06-24
# 631       1978                Cafetera       104.66        11  2024-03-14
# 1475      1628                Cafetera        30.58         2  2024-06-20
# 240       1452                Cafetera        88.56         8  2024-01-29
# 1469      1428                Cafetera        63.53        11  2024-06-19
# 2457      1388                Cafetera        88.66         1  2024-10-25
# 492       1138                Cafetera        92.62         8  2024-02-27
# 2953      1318                Cafetera        98.58         6  2024-12-25
# 1464      1288                Cafetera       124.44         2  2024-06-18
# 328       1422                Cafetera       109.97         2  2024-02-07
# 219       1768                Cafetera       120.32         9  2024-01-26
# 936       1118                Cafetera        67.00        11  2024-04-17
# 737       1918                Cafetera        39.33        10  2024-03-25
# 502       1272                Cafetera       100.92         1  2024-02-28
# 1306      1368                Cafetera        67.26         7  2024-05-28
# 2268      1528                Cafetera        99.75        12  2024-09-29
# 1474      1018                Cafetera       121.43         1  2024-06-20
# 2206      1258                Cafetera        77.56         6  2024-09-20
# 791       1008                Cafetera        42.40        10  2024-04-02
# 2928      1128                Cafetera        90.54         2  2024-12-22
# 1790      1458                Cafetera        86.92         3  2024-07-31
# 452       1582                Cafetera        53.82         7  2024-02-22
# 891       1048                Cafetera        58.81        10  2024-04-13
# 563       1982                Cafetera       117.43         8  2024-03-07
# 562       1052                Cafetera        39.31        11  2024-03-07
# 451       1508                Cafetera       124.68         1  2024-02-22
# 2769      1598                Cafetera       103.75         5  2024-12-01
# 1144      1658                Cafetera        94.79        12  2024-05-10
# 107       1638                Cafetera       123.96         9  2024-01-14
# 1069      1028                Cafetera       108.44         5  2024-05-02
# 1139      1938                Cafetera       107.90        11  2024-05-09
# 1138      1108                Cafetera        84.64         9  2024-05-09
# 1812      1208                Cafetera        54.34         4  2024-08-02
# 1813      1278                Cafetera        67.33         8  2024-08-02
# 903       1698                Cafetera        88.26         1  2024-04-14
# 429       1568                Cafetera        99.10        10  2024-02-20
# 1822      1398                Cafetera        26.98        10  2024-08-03
# 1119      1748                Cafetera        61.63         3  2024-05-07
# 430       1788                Cafetera        45.67         4  2024-02-20
# 1834      1438                Cafetera       111.47         8  2024-08-04
# ...
# 902   Electrodomésticos       317.40
# 2816  Electrodomésticos       773.60
# 1063  Electrodomésticos       708.89
# 1053  Electrodomésticos       296.24
# 1215  Electrodomésticos       566.82
# 43    Electrodomésticos      1048.63
# 1540  Electrodomésticos       984.87
# 2496  Electrodomésticos       353.91
# 1902  Electrodomésticos       208.39
# 1640  Electrodomésticos       418.86
# 1860  Electrodomésticos       906.80
# 352   Electrodomésticos       499.73
# 353   Electrodomésticos      1386.84
# 250   Electrodomésticos        47.91
# 2546  Electrodomésticos       426.55
# 249   Electrodomésticos      1199.00
# 2436  Electrodomésticos       586.17
# 1737  Electrodomésticos       189.00
# 198   Electrodomésticos       121.89
# 2137  Electrodomésticos        53.92
# 1564  Electrodomésticos       652.10
# 1733  Electrodomésticos       345.60
# 2443  Electrodomésticos        44.22
# 2163  Electrodomésticos       206.04
# 2451  Electrodomésticos       629.20
# 2150  Electrodomésticos       334.30
# 1643  Electrodomésticos       414.66
# 2105  Electrodomésticos       452.45
# 539   Electrodomésticos       237.23
# 292   Electrodomésticos       299.67
# 2175  Electrodomésticos       697.41
# 177   Electrodomésticos       929.50
# 302   Electrodomésticos       252.72
# 2469  Electrodomésticos       796.14
# 1606  Electrodomésticos      1412.16
# 1631  Electrodomésticos       260.15
# 384   Electrodomésticos       415.02
# 553   Electrodomésticos       474.64
# 439   Electrodomésticos       721.44
# 184   Electrodomésticos       183.08
# 501   Electrodomésticos       334.72
# 1766  Electrodomésticos      1087.35
# 2046  Electrodomésticos      1211.90
# 2176  Electrodomésticos       416.92
# 622   Electrodomésticos      1210.44
# 1676  Electrodomésticos        84.38
# 547   Electrodomésticos       649.44
# 1486  Electrodomésticos        97.20
# 2323  Electrodomésticos       698.61
# 2413  Electrodomésticos       765.80
# 402   Electrodomésticos       256.44
# 635         Electrónica       377.51
# 555         Electrónica       905.13
# 556         Electrónica      1009.60
# 57          Electrónica       821.80
# 1231        Electrónica      1038.96
# 1876        Electrónica       863.84
# 1636        Electrónica       143.13
# 1871        Electrónica       678.96
# 85          Electrónica        96.90
# 1080        Electrónica       403.20
# 1796        Electrónica       357.80
# 1107        Electrónica      1088.10
# 1164        Electrónica       199.32
# 1270        Electrónica       473.00
# 1262        Electrónica       747.42
# 2845        Electrónica        27.83
# 318         Electrónica       137.94
# 2836        Electrónica       548.90
# 2271        Electrónica       717.44
# 2407        Electrónica      1318.92
# 338         Electrónica       714.78
# 118         Electrónica       243.04
# 1839        Electrónica       182.77
# 625         Electrónica      1436.76
# 343         Electrónica       388.04
# 626         Electrónica       535.62
# 344         Electrónica      1212.53
# 1115        Electrónica      1153.00
# 808         Electrónica       271.88
# 288         Electrónica      1089.90
# 2472        Electrónica       550.55
# 2439        Electrónica       738.12
# 880         Electrónica       646.72
# 247         Electrónica       122.68
# 115         Electrónica       378.25
# 2375        Electrónica       343.30
# 2239        Electrónica       707.68
# 242         Electrónica       700.42
# 312         Electrónica        72.38
# 2189        Electrónica       756.54
# 1762        Electrónica       343.68
# 1795        Electrónica       507.70
# 1398        Electrónica       109.44
# 1399        Electrónica       953.01
# 2474        Electrónica       612.20
# 2349        Electrónica       195.48
# 1980        Electrónica       107.82
# 836         Electrónica       793.70
# 1991        Electrónica       155.36
# 2347        Electrónica       797.79
# 1408        Electrónica       140.40
# 2602        Electrónica       447.58
# 296         Electrónica       487.92
# 1416        Electrónica       530.55
# 2144        Electrónica       422.16
# 1510        Electrónica        81.39
# 2784        Electrónica       345.33
# 2339        Electrónica       304.90
# 1503        Electrónica        89.15
# 2015        Electrónica       401.84
# 2620        Electrónica       645.90
# 1783        Electrónica      1098.36
# 1443        Electrónica       175.76
# 2317        Electrónica       349.68
# 941         Electrónica       351.15
# 2979        Electrónica       502.90
# 2612        Electrónica       331.20
# 2611        Electrónica       497.50
# 2012        Electrónica        51.84
# 168         Electrónica       913.11
# 1218        Electrónica       469.26
# 1541        Electrónica       313.29
# 229         Electrónica        54.84
# 2182        Electrónica       167.80
# 142         Electrónica       535.29
# 2486        Electrónica       493.11
# 2179        Electrónica       251.00
# 655         Electrónica        99.78
# 825         Electrónica       494.62
# 481         Electrónica        47.21
# 214         Electrónica        58.30
# 1570        Electrónica        92.79
# 1568        Electrónica       355.62
# 2584        Electrónica       314.52
# 90          Electrónica      1150.00
# 2336        Electrónica       164.96
# 2662        Electrónica       620.00
# 295         Electrónica       196.92
# 1366        Electrónica       600.05
# 762         Electrónica       345.90
# 2517        Electrónica       832.96
# 2518        Electrónica       410.82
# 1027        Electrónica        54.61
# 473         Electrónica       323.29
# 1961        Electrónica        36.21
# 472         Electrónica       106.23
# 1786        Electrónica       682.08
# 1011        Electrónica      1004.22
# 1971        Electrónica       189.87
# 1442        Electrónica       425.85
# 2592        Electrónica       640.64
# 848         Electrónica      1483.20
# 2310        Electrónica      1480.80
# 91          Electrónica       679.30
# 1181        Electrónica       274.59
# 1191        Electrónica       376.55
# 574         Electrónica       111.33
# 1146        Electrónica       547.40
# 727         Electrónica       237.60
# 1140        Electrónica       901.56
# 475         Electrónica        57.28
# 1014        Electrónica      1056.24
# 1006        Electrónica       258.75
# 462         Electrónica       293.22
# 2950        Electrónica       952.96
# 454         Electrónica       719.88
# 2960        Electrónica       440.40
# 2006        Electrónica       110.79
# 2011        Electrónica       101.00
# 2110        Electrónica      1311.31
# 2107        Electrónica       166.89
# 446         Electrónica       322.02
# 444         Electrónica       260.80
# 2975        Electrónica       661.76
# 971         Electrónica        56.73
# 2091        Electrónica       698.10
# 434         Electrónica       930.00
# 2058        Electrónica       103.95
# 960         Electrónica       230.07
# 1029        Electrónica       422.16
# 920         Electrónica       839.19
# 34          Electrónica       435.25
# 1926        Electrónica       374.76
# 1825        Electrónica       494.90
# 1827        Electrónica        90.19
# 1134        Electrónica      1276.68
# 2853        Electrónica       128.91
# 2247        Electrónica       730.96
# 354         Electrónica       592.08
# 1105        Electrónica       223.17
# 355         Electrónica       296.65
# 356         Electrónica       374.00
# 550         Electrónica      1488.12
# 357         Electrónica        97.62
# 1881        Electrónica       125.56
# 55          Electrónica       770.77
# 2892        Electrónica       510.24
# 2329        Electrónica       556.70
# 54          Electrónica       650.28
# 47          Electrónica       537.55
# 2205        Electrónica       730.44
# 2907        Electrónica      1189.50
# 2913        Electrónica       873.63
# 1088        Electrónica       135.18
# 517         Electrónica       701.34
# 1763        Electrónica        69.68
# 2998        Electrónica       698.95
# 2501        Electrónica       236.67
# 2438        Electrónica       122.20
# 634         Electrónica       624.10
# 253         Electrónica       118.66
# 2426        Electrónica       374.40
# 2425        Electrónica       168.15
# 1533        Electrónica       822.78
# 770         Electrónica       779.87
# 201         Electrónica       639.73
# 119         Electrónica       478.65
# 2563        Electrónica       238.52
# 1290        Electrónica       210.12
# 1620        Electrónica       460.60
# 2453        Electrónica       776.44
# 285         Electrónica       176.86
# 623         Electrónica      1024.92
# 679         Electrónica      1186.24
# 1686        Electrónica        97.36
# 2519        Electrónica       372.44
# 2734        Electrónica       709.20
# 1567        Electrónica       753.39
# 657         Electrónica       633.78
# 202         Electrónica       191.24
# 1738        Electrónica      1269.12
# 2498        Electrónica       329.34
# 2458        Electrónica       440.40
# 1210        Electrónica       679.36
# 587         Electrónica      1304.60
# 2346        Electrónica        64.37
# 248         Electrónica      1452.00
# 2601        Electrónica       286.02
# 1440        Electrónica       193.92
# 1634        Electrónica       463.80
# 2351        Electrónica       268.16
# 1635        Electrónica        74.56
# 236         Electrónica        34.50
# 238         Electrónica       115.81
# 2703        Electrónica       767.28
# 2337        Electrónica       588.30
# 245         Electrónica       727.32
# 787         Electrónica       103.69
# 2454        Electrónica       765.36
# 1740        Electrónica       864.29
# 718         Electrónica      1264.34
# 1924        Electrónica       237.96
# 771         Electrónica       834.79
# 2190        Electrónica       418.05
# 516         Electrónica       394.35
# 1898        Electrónica       204.87
# 2902        Electrónica       634.13
# 140         Electrónica       277.40
# 495         Electrónica       578.97
# 497         Electrónica       798.56
# 768         Electrónica       394.24
# 583         Electrónica       162.57
# 1389        Electrónica       392.77
# 1556        Electrónica       823.68
# 946         Electrónica       172.80
# 2059        Electrónica       622.53
# 2064        Electrónica       569.52
# 1448        Electrónica       615.20
# 961         Electrónica       372.54
# 2990        Electrónica       276.72
# 2080        Electrónica       254.88
# 1436        Electrónica       184.80
# 2093        Electrónica       647.12
# 2980        Electrónica       841.56
# 1434        Electrónica       357.95
# 1487        Electrónica       412.38
# 1426        Electrónica       528.16
# 1947        Electrónica        94.10
# 2973        Electrónica       239.95
# 1509        Electrónica       665.64
# 2118        Electrónica       424.98
# 2007        Electrónica       991.54
# 986         Electrónica       652.48
# 14          Electrónica       611.73
# 1527        Electrónica       378.88
# 15          Electrónica       370.45
# 200         Electrónica       223.84
# 2945        Electrónica      1020.91
# 2944        Electrónica       246.00
# 1542        Electrónica       370.74
# 1387        Electrónica       245.94
# 1382        Electrónica       349.56
# 1425        Electrónica       241.65
# 897         Electrónica       117.89
# 1899        Electrónica       200.06
# 2061        Electrónica       190.60
# 819         Electrónica       520.73
# 255         Electrónica       377.64
# 1278        Electrónica      1353.11
# 1222        Electrónica       279.93
# 881         Electrónica       511.04
# 1826        Electrónica       799.90
# 2275        Electrónica       630.36
# 120         Electrónica       234.94
# 882         Electrónica       191.80
# 2348        Electrónica       214.65
# 100         Electrónica        32.30
# 1782        Electrónica       869.76
# 1837        Electrónica       194.97
# 2635        Electrónica       472.16
# 418         Electrónica       348.45
# 995         Electrónica       593.25
# 1417        Electrónica       858.13
# 1157        Electrónica       321.93
# 2376        Electrónica       369.45
# 739         Electrónica       269.48
# 1806        Electrónica       665.36
# 1250        Electrónica       487.08
# 1170        Electrónica       336.15
# 993         Electrónica       866.00
# 1511        Electrónica       476.28
# 696         Electrónica       418.68
# 1407        Electrónica       474.36
# 810         Electrónica       732.78
# 2555        Electrónica       867.60
# 2958        Electrónica       580.00
# 1990        Electrónica       379.60
# 1239        Electrónica        43.31
# 445         Electrónica       147.03
# 557         Electrónica       239.36
# 99          Electrónica        57.34
# 2789        Electrónica       669.60
# 304         Electrónica       196.92
# 1755        Electrónica       457.04
# 2805        Electrónica       275.45
# 2810        Electrónica       597.74
# 2050        Electrónica       490.05
# 716         Electrónica       122.49
# 1784        Electrónica       252.35
# 969         Electrónica       428.78
# 730         Electrónica       138.12
# 1192        Electrónica       183.34
# 1221        Electrónica      1060.18
# 2094        Electrónica       192.30
# 1787        Electrónica       677.60
# 1788        Electrónica      1177.55
# 2029        Electrónica       854.80
# 2028        Electrónica       604.32
# 1493        Electrónica      1253.52
# 2303        Electrónica       285.92
# 2301        Electrónica       336.14
# 1156        Electrónica        79.54
# 1230        Electrónica       415.80
# 2365        Electrónica       104.70
# 1807        Electrónica       213.82
# 1872        Electrónica       319.96
# 1718        Electrónica       638.55
# 1859        Electrónica      1387.92
# 632         Electrónica       332.85
# 2440        Electrónica        67.41
# 141         Electrónica      1057.77
# 2202        Electrónica       252.57
# 1065        Electrónica      1160.06
# 1905        Electrónica      1115.84
# 2710        Electrónica       927.44
# 2238        Electrónica       222.88
# 636         Electrónica       511.29
# 370         Electrónica       875.70
# 582         Electrónica       689.90
# 2448        Electrónica       704.52
# 528         Electrónica       864.36
# 1331        Electrónica       191.75
# 2459        Electrónica       825.72
# 527         Electrónica       731.79
# 886         Electrónica       272.00
# 1882        Electrónica       874.24
# 2890        Electrónica       101.58
# 887         Electrónica       105.20
# 365         Electrónica       562.90
# 781         Electrónica       713.86
# 254         Electrónica       189.96
# 1005        Electrónica        96.60
# 1845        Electrónica       179.88
# 230         Electrónica       298.71
# 1261        Electrónica       914.22
# 551         Electrónica        33.14
# 2224        Electrónica        80.78
# 1973        Electrónica       684.18
# 203         Electrónica       240.30
# 2383        Electrónica       505.89
# 1545        Electrónica       331.95
# 2384        Electrónica       164.54
# 859         Electrónica       136.92
# 2154        Electrónica       237.78
# 612         Electrónica       318.00
# 392         Electrónica       502.40
# 760         Electrónica       391.79
# 152         Electrónica       424.80
# 211         Electrónica       622.64
# 1950        Electrónica       501.04
# 479         Electrónica       491.19
# 1279        Electrónica       391.38
# 2740        Electrónica       811.26
# 2669        Electrónica       317.64
# 1282        Electrónica       297.96
# 220         Electrónica       714.16
# 643         Electrónica       166.98
# 1668        Electrónica       369.32
# 746         Electrónica        42.72

# %%
df_ventas_final.head()
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02
# 1       811    Lámpara de mesa       105.10         5  2024-01-02
# 2      1156           Secadora        97.96         3  2024-01-02
# 3      1372           Heladera       114.35         8  2024-01-02
# 4      1546           Secadora       106.21         4  2024-01-02
#
#            categoria  valor_venta
# 0         Decoración       349.70
# 1         Decoración       525.50
# 2  Electrodomésticos       293.88
# 3  Electrodomésticos       914.80
# 4  Electrodomésticos       424.84

# %%
# Listamos los registros de marketing ordenados por producto, forma ascendente
#df_marketing2 = df_marketing.sort_values(by="producto", ascending=True)
df_marketing.sort_values(by=["producto","canal"])

df_marketing.head(6)
# Out:
#    id_campanha         producto  canal  costo_mrkt fecha_inicio  fecha_fin
# 0           74  Adorno de pared     TV        4.81   2024-03-20 2024-05-03
# 1           12           Tablet   RRSS        3.40   2024-03-26 2024-05-13
# 2           32  Lámpara de mesa  Email        5.54   2024-03-28 2024-04-20
# 3           21       Smartphone   RRSS        6.37   2024-03-29 2024-05-16
# 4           58         Alfombra  Email        4.25   2024-03-31 2024-05-05
# 5           85       SmartWatch     TV        5.07   2024-04-01 2024-05-05

# %%
# Para evitar duplicados, habria que agrupar marketing antes de hacer el merge
# (a costa de perder la fecha)
df_marketing_avg = df_marketing.groupby(["producto"], as_index=False)["costo_mrkt"].mean()
df_marketing_avg
# Out:
#                   producto  costo_mrkt
# 0          Adorno de pared    4.683333
# 1                 Alfombra    5.820000
# 2               Aspiradora    5.486667
# 3              Auriculares    5.080000
# 4                 Batidora    5.093333
# 5                 Cafetera    6.053333
# 6               Candelabro    4.883333
# 7   Consola de videojuegos    4.256667
# 8                 Cortinas    5.786667
# 9        Cuadro decorativo    5.283333
# 10          Cámara digital    5.466667
# 11   Elementos de cerámica    5.623333
# 12       Espejo decorativo    4.963333
# 13      Freidora eléctrica    4.520000
# 14                Heladera    4.370000
# 15         Horno eléctrico    4.630000
# 16       Jarrón decorativo    4.423333
# 17                  Laptop    5.063333
# 18                Lavadora    3.950000
# 19         Lámpara de mesa    5.310000
# 20              Microondas    4.730000
# 21     Parlantes Bluetooth    4.456667
# 22        Plancha de vapor    4.706667
# 23               Proyector    4.156667
# 24       Rincón de plantas    5.483333
# 25                Secadora    4.863333
# 26              SmartWatch    4.833333
# 27              Smartphone    5.266667
# 28                  Tablet    4.240000
# 29               Televisor    4.376667

# %%
# Unir los datasets ventas y marketing por columna 'producto'

# Aqui tenemos dos caminos, unir ventas con df_marketing que tiene duplicados
# met 1
ventas_marketing1 = pd.merge(df_ventas_final, df_marketing, on="producto", how="left")

# unir df_ventas con df_marketing_avg que no tiene duplicados, pero no tiene fechas
# met 2
ventas_marketing_avg = pd.merge(df_ventas_final, df_marketing_avg, on="producto", how="inner")

# %%
ventas_marketing1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8994 entries, 0 to 8993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_venta      8994 non-null   int64
#  1   producto      8994 non-null   object
#  2   precio_unit   8994 non-null   float64
#  3   cantidad      8994 non-null   int64
#  4   fecha_venta   8994 non-null   datetime64[ns]
#  5   categoria     8994 non-null   object
#  6   valor_venta   8994 non-null   float64
#  7   id_campanha   8994 non-null   int64
#  8   canal         8994 non-null   object
#  9   costo_mrkt    8994 non-null   float64
#  10  fecha_inicio  8994 non-null   datetime64[ns]
#  11  fecha_fin     8994 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(3), object(3)
# memory usage: 843.3+ KB

# %%
ventas_marketing_avg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio_unit  2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
#  6   valor_venta  2998 non-null   float64
#  7   costo_mrkt   2998 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 187.5+ KB

# %%
# Verificar coincidencias (muestra)
ventas_marketing1.sort_values(by=["producto", "precio_unit"], ascending=True)
ventas_marketing1.head(6)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 1       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 2       792  Cuadro decorativo        69.94         5  2024-01-02  Decoración
# 3       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
# 4       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
# 5       811    Lámpara de mesa       105.10         5  2024-01-02  Decoración
#
#    valor_venta  id_campanha  canal  costo_mrkt fecha_inicio  fecha_fin
# 0        349.7            1   RRSS        5.27   2024-04-27 2024-06-04
# 1        349.7           31  Email        5.28   2024-08-15 2024-09-12
# 2        349.7           61     TV        5.30   2024-11-05 2024-12-23
# 3        525.5           32  Email        5.54   2024-03-28 2024-04-20
# 4        525.5            2   RRSS        5.88   2024-05-30 2024-06-29
# 5        525.5           62     TV        4.51   2024-08-26 2024-10-07

# %%
# Nota1: si unieron ventas con marketing, obtienen 8994 registros
# Nota2: si unieron ventas con marketing_avg obtienen 2998 registros

# %% [markdown]
# ### Analizamos el impacto de la campaña

# %%
# Nos quedamos solo con los registros de ventas durante la campaña de marketing
ganancias_marketing = ventas_marketing1.query("fecha_venta > fecha_inicio & fecha_venta < fecha_fin")

# Nota: si trabajan con el DF marketing1 pueden aplicar el filtro,
# si trabajan con dataframe marketing_avg, al no tener fecha, no apliquen el filtro.


# Seleccionamos solo los campos que nos interesan: "producto", "valor_venta", "costo"
ganancias_marketing = ganancias_marketing[["producto", "valor_venta", "costo_mrkt","cantidad"]]
ganancias_marketing.sort_values(by="producto", ascending=True)
ganancias_marketing.head(6)
# Out:
#              producto  valor_venta  costo_mrkt  cantidad
# 2091  Adorno de pared       553.91        4.81         7
# 2124  Adorno de pared       579.54        4.81         6
# 2160  Adorno de pared       286.68        4.81         4
# 2256  Adorno de pared       831.20        4.81         8
# 2286  Lámpara de mesa        44.88        5.54         1
# 2298           Tablet       394.24        3.40        11

# %%
# Agrupamos por producto y hacemos una agregación por "valor de venta" y "costo"
ganancias_marketing = ganancias_marketing.groupby("producto")[["valor_venta","costo_mrkt","cantidad"]].sum()
ganancias_marketing
# Out:
#                         valor_venta  costo_mrkt  cantidad
# producto
# Adorno de pared            15110.72      129.80       192
# Alfombra                   14786.14      172.57       218
# Aspiradora                 12844.78      163.92       182
# Auriculares                19840.99      201.70       246
# Batidora                   22137.37      212.08       283
# Cafetera                   14459.17      160.84       185
# Candelabro                  5700.53       63.08        78
# Consola de videojuegos      7785.49       68.69        99
# Cortinas                   14623.15      166.43       184
# Cuadro decorativo          17482.27      174.36       243
# Cámara digital             19705.88      229.58       274
# Elementos de cerámica       8024.73      113.70       153
# Espejo decorativo          10882.18      114.30       122
# Freidora eléctrica          7076.03       73.71        94
# Heladera                    8233.36       60.12       106
# Horno eléctrico            17244.82      154.30       221
# Jarrón decorativo          14657.18      132.15       193
# Laptop                     11824.25      115.50       139
# Lavadora                    8738.74       70.89       113
# Lámpara de mesa            17461.57      229.31       239
# Microondas                 14865.68      104.89       172
# Parlantes Bluetooth        17942.96      144.45       232
# Plancha de vapor           11776.61      148.97       157
# Proyector                  11788.86      109.37       164
# Rincón de plantas           8098.52       77.22        96
# Secadora                    6057.90       66.55        85
# SmartWatch                 13603.77      124.18       168
# Smartphone                 12782.03      144.81       167
# Tablet                     13719.93      133.12       211
# Televisor                  11508.62       86.81       160

# %% [markdown]
# ## ACA hay un ERROR ???
# por qué no se multiplica:
#
# cantidad vendida x costo_mrkt (que es unitario)

# %%
# Generamos una nueva columna con la diferencia entre lo vendido y lo invertido en la campaña

ganancias_marketing["ganancia_neta"] = ganancias_marketing['valor_venta'] -(ganancias_marketing['costo_mrkt'] * ganancias_marketing['cantidad'])

ganancias_marketing = ganancias_marketing.sort_values(by="ganancia_neta", ascending=False)

ganancias_marketing.head()
# Out:
#                         valor_venta  costo_mrkt  cantidad  ganancia_neta
# producto
# Heladera                    8233.36       60.12       106        1860.64
# Consola de videojuegos      7785.49       68.69        99         985.18
# Candelabro                  5700.53       63.08        78         780.29
# Lavadora                    8738.74       70.89       113         728.17
# Rincón de plantas           8098.52       77.22        96         685.40

# %%
#
# Crear un gráfico de barras apilado para comparar valor_venta y costo por producto

ganancias_marketing[["valor_venta", "costo_mrkt"]].plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Comparación de Valor de Venta y Costo por Producto")
plt.xlabel("Producto")
plt.ylabel("Monto")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Solución al problema de los duplicados**

# %%
# Hacemos el merge entre marketing y ventas por columna producto
marketing_ventas = pd.merge(df_marketing, df_ventas_final, on="producto", how="inner")
marketing_ventas.sort_values(by="producto", ascending=True)
marketing_ventas.head(6)
# Out:
#    id_campanha         producto canal  costo_mrkt fecha_inicio  fecha_fin  \
# 0           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 1           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 2           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 3           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 4           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 5           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
#
#    id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta
# 0       630        71.99         9  2024-01-04  Decoración       647.91
# 1       560        57.62         6  2024-01-07  Decoración       345.72
# 2       830        67.23        10  2024-01-10  Decoración       672.30
# 3        20        90.21         2  2024-01-14  Decoración       180.42
# 4       260       101.48         9  2024-01-15  Decoración       913.32
# 5       430        81.76         5  2024-01-18  Decoración       408.80

# %%
# filtramos solo aquellos productos que se hayan vendido dentro de la campaña
marketing_ventas_pp1 = marketing_ventas.query("fecha_venta > fecha_inicio & fecha_venta < fecha_fin")
marketing_ventas_pp1.head(6)
# Out:
#     id_campanha         producto canal  costo_mrkt fecha_inicio  fecha_fin  \
# 24           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 25           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 26           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 27           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 28           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 29           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
#
#     id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta
# 24       780        79.13         7  2024-03-21  Decoración       553.91
# 25       270        96.59         6  2024-03-22  Decoración       579.54
# 26       210        71.67         4  2024-03-24  Decoración       286.68
# 27       730       103.90         8  2024-03-28  Decoración       831.20
# 28       390        87.52         8  2024-04-01  Decoración       700.16
# 29       570        64.18         7  2024-04-03  Decoración       449.26

# %%
# Calculamos el total_ventas por producto haciendo valor_venta * cantidad
marketing_ventas_pp2 = marketing_ventas_pp1.copy() # para eliminar la advertencia
#marketing_ventas_pp2.info()

marketing_ventas_pp2["total_venta"] = (
    marketing_ventas_pp2["valor_venta"] * marketing_ventas_pp2["cantidad"]
)
marketing_ventas_pp2.head(6)
# Out:
#     id_campanha         producto canal  costo_mrkt fecha_inicio  fecha_fin  \
# 24           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 25           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 26           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 27           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 28           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
# 29           74  Adorno de pared    TV        4.81   2024-03-20 2024-05-03
#
#     id_venta  precio_unit  cantidad fecha_venta   categoria  valor_venta  \
# 24       780        79.13         7  2024-03-21  Decoración       553.91
# 25       270        96.59         6  2024-03-22  Decoración       579.54
# 26       210        71.67         4  2024-03-24  Decoración       286.68
# 27       730       103.90         8  2024-03-28  Decoración       831.20
# 28       390        87.52         8  2024-04-01  Decoración       700.16
# 29       570        64.18         7  2024-04-03  Decoración       449.26
#
#     total_venta
# 24      3877.37
# 25      3477.24
# 26      1146.72
# 27      6649.60
# 28      5601.28
# 29      3144.82

# %%
# Agrupamos el dataframe por producto  usando agg

# Agregar total_venta como el promedio, elimina el impacto de los datos duplicados
# Y seguimos agregando costo_mrkt como la suma de lo invertido en cada canal
ganancias_marketing = marketing_ventas_pp2.groupby("producto").agg(
    {
        "total_venta": "mean",
        "costo_mrkt": "sum",
    }
)
#ganancias_marketing

# %%
# A partir de venta_total y costo, calculamos la ganancia obtenida
ganancias_marketing["ganancia"] = ganancias_marketing["total_venta"]- ganancias_marketing["costo_mrkt"]
ganancias_marketing = ganancias_marketing.sort_values(by="ganancia", ascending=False)
ganancias_marketing.head(3)
# Out:
#             total_venta  costo_mrkt     ganancia
# producto
# Microondas  6164.674783      104.89  6059.784783
# Heladera    5786.587143       60.12  5726.467143
# Cafetera    5388.738000      160.84  5227.898000

# %%
# Creamos un gráfico de barras apilado para comparar valor_venta y costo por producto
ganancias_marketing[["total_venta", "costo_mrkt"]].plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Comparación de Valor de Venta y Costo por Producto")
plt.xlabel("Producto")
plt.ylabel("Monto")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ==========================================================

# %% [markdown]
# # Entrega Final

# %% [markdown]
# # Etapa 3 - Análisis de Datos

# %% [markdown]
# Objetivo: Realizar análisis estadístico y exploratorio sobre los datos procesados.
# sobre:
# * df_ventas
# * df_marketing

# %% [markdown]
# ## 1 - Estadística Descriptiva

# %% [markdown]
# En la Etapa 2 - Limpieza de datos, obtuvimos los dataframes:
#
# * df_ventas
# * df_marketing
#
# Usamos el método describe para obtener un resumen de las:
# * Medidas de posición
# * Medidas de dispersión o variabilidad

# %%
# Dataframe ventas
df_ventas_final[["precio_unit", "cantidad", "valor_venta"]].describe()
# df_ventas.describe()
# Out:
#        precio_unit     cantidad  valor_venta
# count  2998.000000  2998.000000  2998.000000
# mean     75.291318     6.502668   489.357412
# std      28.736008     3.455107   334.281817
# min      26.000000     1.000000    26.300000
# 25%      50.030000     3.000000   220.920000
# 50%      75.205000     7.000000   418.065000
# 75%     100.067500     9.000000   709.920000
# max     124.970000    12.000000  1488.120000

# %%
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo_mrkt fecha_inicio  fecha_fin
# 0           74  Adorno de pared     TV        4.81   2024-03-20 2024-05-03
# 1           12           Tablet   RRSS        3.40   2024-03-26 2024-05-13
# 2           32  Lámpara de mesa  Email        5.54   2024-03-28 2024-04-20
# 3           21       Smartphone   RRSS        6.37   2024-03-29 2024-05-16
# 4           58         Alfombra  Email        4.25   2024-03-31 2024-05-05

# %%
df_marketing.groupby("canal")["costo_mrkt"].describe()
# Out:
#        count      mean       std   min     25%    50%     75%   max
# canal
# Email   30.0  4.840000  0.898773  2.95  4.2125  4.895  5.5075  6.84
# RRSS    30.0  5.030333  0.894101  3.16  4.5600  5.130  5.5425  7.16
# TV      30.0  4.915667  1.063215  3.06  4.3725  4.795  5.5400  7.39

# %% [markdown]
# ## 2 - EDA (Análisis Exploratorio de Datos)

# %% [markdown]
# Realizar un análisis exploratorio utilizando visualizaciones para identificar patrones y tendencias en las ventas.

# %% [markdown]
# ### Gráficos histogramas

# %%
# Histograma de precios

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Graficamos
sns.histplot(data=df_ventas, x="precio_unit", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma cantidades

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Graficamos
sns.histplot(data=df_ventas, x="cantidad", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Cantidades")
plt.xlabel("Cantidad")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma ventas_totales

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Graficamos
sns.histplot(data=df_ventas_final, x="valor_venta", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Ventas Totales")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma costo marketing

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Graficamos
sns.histplot(data=df_marketing, x="costo_mrkt", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Gráficos Boxplot

# %%
# Boxplot Ventas

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="Set3") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(12, 6)) #ancho x alto = resolucion

# Subplots, dividen al lienzo en partes
plt.subplot(1,3,1) # (1,3,1) => (1 fila, 3 columans, bloque 1)

# Subplot 1
sns.boxplot(data=df_ventas_final, y="precio_unit")
plt.title("Boxplot de Precios")
plt.ylabel("")

# Subplot 2
plt.subplot(1,3,2) # (1,3,2) => (1 fila, 3 columans, bloque 2)
sns.boxplot(data=df_ventas_final, y="valor_venta")
plt.title("Boxplot de Valor de venta")
plt.ylabel("")


# Subplot 3
plt.subplot(1,3,3) # (1,3,3) => (1 fila, 3 columans, bloque 3)
sns.boxplot(data=df_ventas_final, y="cantidad")
plt.title("Boxplot de Cantidad")
plt.ylabel("")

plt.show()

# %% [markdown]
# ### Boxplot Ventas con valores estadísticos

# %%
# @title
def rgb_to_hex(r, g, b):
    #--------------------------------------------------------------
    # Converts RGB values (0-255) to a hexadecimal color code.
    return f'#{r:02X}{g:02X}{b:02X}'


def hex_to_rgb(hex_color):
    #--------------------------------------------------------------
    # Converts a hexadecimal color code ( '#RRGGBB' or 'RRGGBB')
    # to an RGB tuple (R, G, B).
    # Remove '#' if present
    hex_color = hex_color.lstrip('#')

    # Handle 3-digit shorthand hex codes (e.g., #F00 -> #FF0000)
    if len(hex_color) == 3:
        hex_color = ''.join([c * 2 for c in hex_color])

    # Convert each two-character hex pair to its decimal equivalent
    r = int(hex_color[0:2], 16)
    g = int(hex_color[2:4], 16)
    b = int(hex_color[4:6], 16)
    return (r, g, b)

def float_RGB_to_int_RGB(float_rgb_tuple):
    #--------------------------------------------------------------------
    # Convierte una tupla RGB de float(0.0-1.0) a tupla RGB de int(0-255)
    return tuple(int(c * 255) for c in float_rgb_tuple)

def fRGB_to_iRGB(float_rgb_tuple):
    #---------------------------------
    # Convierte una tupla RGB de float(0.0-1.0) a tupla RGB de int(0-255)
    return tuple(int(c * 255) for c in float_rgb_tuple)

def int_RGB_to_float_RGB(r_int, g_int, b_int):
    # Converts integer RGB values (0-255) to float RGB values (0.0-1.0).
    # Returns: A tuple containing the float red, green, blue (0.0-1.0).
    r_float = r_int / 255.0
    g_float = g_int / 255.0
    b_float = b_int / 255.0
    return r_float, g_float, b_float


# Example usage:
#red_hex = rgb_to_hex(255, 0, 0)
#print(f"Red RGB to Hex: {red_hex}")

#blue_hex = rgb_to_hex(0, 0, 255)
#print(f"Blue RGB to Hex: {blue_hex}")

# %%
# Boxplot Ventas con valores estadísticos

# Estilo y tamaños de palette = # deep, muted, bright, Set1, Set2, Set3
# Obtener los colores de la paleta 'Pastel1'
pastel_colors = sns.color_palette("Pastel1")
pastel_colors[0] = (1.0, 1.0, 0.9019607843137255)

#custom_palette = sns.color_palette(["#FFFFe6", "#FFFFe6", "#FFFFe6","#FFFFe6", "#FFFFe6", "#FFFFe6", "#FFFFe6","#FFFFe6",])
# Por ejemplo, elegimos el segundo color de la paleta (indice 1)
# Se puede cambiar el indice para seleccionar otro color de la paleta
box_bgcolor = pastel_colors[0]

sns.set_theme(style="darkgrid", palette= pastel_colors)
print("\n")
plt.figure(figsize=(12, 6)) #ancho x alto = resolucion

# Subplots, dividen al lienzo en partes
ax1 = plt.subplot(1,3,1) # (1 fila, 3 columans, bloque 1)

# La paleta aquí controla los colores si no usas hue, o el borde si usas boxprops
# Usamos 'boxprops' para cambiar el color de relleno de las cajas
# sns.boxplot(data=df_marketing, x="canal", y="costo_mrkt",
#            boxprops=dict(facecolor=specific_box_color), # Aquí se aplica el color a las cajas
#            palette="Pastel1")

# Subplot 1: Precio
sns.boxplot(data=df_ventas_final, y="precio_unit", ax=ax1,boxprops=dict(facecolor=box_bgcolor))

plt.title("Boxplot de Precios\n", fontsize=16)
plt.ylabel("")
stats_precio = df_ventas_final["precio_unit"].describe()
ax1.text(0.23, stats_precio["max"], f'Max: {stats_precio["max"]:.2f}', verticalalignment='center', color='red',fontsize=10)
ax1.text(0.2, stats_precio["75%"], f'Q3: {stats_precio["75%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax1.text(0.2, stats_precio["50%"], f' Me: {stats_precio["50%"]:.2f}', verticalalignment='center', color='#004d00',fontsize=11)
ax1.text(0.2, stats_precio["25%"], f'Q1: {stats_precio["25%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax1.text(0.23, stats_precio["min"], f'Min: {stats_precio["min"]:.2f}', verticalalignment='center', color='red',fontsize=10)


ax2 = plt.subplot(1,3,2) # (1 fila, 3 columans, bloque 2)
# Subplot 2: Valor de venta
sns.boxplot(data=df_ventas_final, y="valor_venta", ax=ax2)
plt.title("Boxplot de Valor de venta\n", fontsize=16)
plt.ylabel("")
stats_valor_venta = df_ventas_final["valor_venta"].describe()
ax2.text(0.23, stats_valor_venta["max"], f'Max: {stats_valor_venta["max"]:.2f}', verticalalignment='center', color='red',fontsize=10)
ax2.text(0.2, stats_valor_venta["75%"], f'Q3: {stats_valor_venta["75%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax2.text(0.2, stats_valor_venta["50%"], f'Me: {stats_valor_venta["50%"]:.2f}', verticalalignment='center', color='#006600',fontsize=11)
ax2.text(0.2, stats_valor_venta["25%"], f'Q1: {stats_valor_venta["25%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax2.text(0.23, stats_valor_venta["min"], f'Min: {stats_valor_venta["min"]:.2f}', verticalalignment='center', color='red',fontsize=10)


ax3 = plt.subplot(1,3,3) # (1 fila, 3 columans, bloque 3)
# Subplot 3: Cantidad
sns.boxplot(data=df_ventas_final, y="cantidad", ax=ax3)
plt.title("Boxplot de Cantidad\n", fontsize=16)
plt.ylabel("")
stats_cantidad = df_ventas_final["cantidad"].describe()
ax3.text(0.23, stats_cantidad["max"], f'Max: {stats_cantidad["max"]:.2f}', verticalalignment='center', color='red',fontsize=10)
ax3.text(0.2, stats_cantidad["75%"], f'Q3: {stats_cantidad["75%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax3.text(0.2, stats_cantidad["50%"], f'Me: {stats_cantidad["50%"]:.2f}', verticalalignment='center', color='#006600',fontsize=11)
ax3.text(0.2, stats_cantidad["25%"], f'Q1: {stats_cantidad["25%"]:.2f}', verticalalignment='center', color='blue',fontsize=10)
ax3.text(0.23, stats_cantidad["min"], f'Min: {stats_cantidad["min"]:.2f}', verticalalignment='center', color='red',fontsize=10)

plt.tight_layout() # Ajusta el layout para evitar solapamientos
plt.show()

# %% [markdown]
# # BORRAR !!

# %%
# @title
import matplotlib.pyplot as plt
import seaborn as sns

tcolor = (1.0, 1.0, 0.8)
#print(f"mi_rgb = {fRGB_to_iRGB(tcolor)}")

myrgb = float_RGB_to_int_RGB(tcolor)
#print(f"mi hex= {rgb_to_hex(myrgb[0],myrgb[1],230)}")
#print(f"255,255,230= {int_RGB_to_float_RGB(255,255, 230)}")

# Obtener los colores de la paleta 'Pastel1'
pastel_colors = sns.color_palette("Pastel1")
pastel_colors[0] = (1.0, 1.0, 0.9019607843137255)

#-------------------------------------------------
# Get hex codes for the "pastel" palette
hex_codes = sns.color_palette( pastel_colors).as_hex()
#print(hex_codes)

# Por ejemplo, elegimos el segundo color de la paleta (índice 1)
# Puedes cambiar el índice para seleccionar otro color de la paleta
specific_box_color = pastel_colors[5]

#print(specific_box_color)

# Configurar el estilo de Seaborn
# Mantendremos el fondo del eje blanco o por defecto para resaltar el color de la caja
sns.set_theme(style="darkgrid", palette="Paired")

plt.figure(figsize=(12, 6))

# Graficamos el boxplot
# Usamos 'boxprops' para cambiar el color de relleno de las cajas
sns.boxplot(data=df_marketing, x="canal", y="costo_mrkt",
            boxprops=dict(facecolor=specific_box_color), # Aquí se aplica el color a las cajas
            palette="Pastel1", # La paleta aquí controla los colores si no usas hue, o el borde si usas boxprops
            hue="canal", legend=False)
# Título y subtítulo
plt.title("Distribución del Costo por Canal de Marketing (Cajas de color personalizado)", fontsize=16, pad=15)

plt.xlabel("Canales de Marketing", fontsize=12)
plt.ylabel("")

# Rotación y tamaño de labels del eje X
plt.xticks(rotation=45, fontsize=10)

plt.show()

# %%
# @title
# Ejemplo de uso:
float_color = (1.0, 1.0, 0.8) # Un color amarillo claro de la paleta Pastel1
int_color = float_rgb_to_int_rgb(float_color)
print(f"Color flotante RGB: {float_color}")
print(f"Color entero RGB (0-255): {int_color}")

# Otro color de Pastel1
float_color_2 = (0.6352941176470588, 0.8117647058823529, 0.8901960784313725)
int_color_2 = float_rgb_to_int_rgb(float_color_2)
print(f"Color flotante RGB: {float_color_2}")
print(f"Color entero RGB (0-255): {int_color_2}")

# %%
# Boxplot marketing

# Estilo y tamaños # deep, muted, bright, Set1, Set2, Set3
sns.set_theme(style="darkgrid", palette="Paired", rc={'axes.facecolor': '#F0F8FF', 'figure.facecolor': '#F0F8FF'}) # 'F0F8FF' es un color azul claro
plt.figure(figsize=(12, 6))

# Graficamos
sns.boxplot(data=df_marketing, x="canal", y="costo_mrkt", palette="Pastel1", hue="canal")
# sns.boxplot(data=df_marketing, y="costo_mrkt") # asi grafico costo para todos los canales

# Título y subtítulo
plt.title("Distribución del Costo por Canal de Marketing", fontsize=16, pad=15)

plt.xlabel("Canales de Marketing", fontsize=12)
plt.ylabel("")

# Rotación y tamaño de labels del eje X
plt.xticks(rotation=0, fontsize=14)

plt.show()

# %% [markdown]
# ## 3 - Correlación

# %%
# Primero calculamos la matríz de correlación usando las variables numéricas
correlacion = df_ventas_final[['precio_unit', 'cantidad', 'valor_venta']].corr() #.corr() calcula la matriz de correlacion
print("\nMatriz de correlación:")
print(correlacion)
# Out:
# Matriz de correlación:
#              precio_unit  cantidad  valor_venta
# precio_unit     1.000000 -0.002388     0.558846
# cantidad       -0.002388  1.000000     0.773009
# valor_venta     0.558846  0.773009     1.000000

# %%
# Representamos las variables en un scatterplot o gráfico de dispersión
# Y agregamos una línea de tendencia

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.scatterplot(data=df_ventas_final, x="precio_unit", y="cantidad")

# agrega una linea de regresion
sns.regplot(
    data=df_ventas_final,
    x="precio_unit",
    y="valor_venta",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)

plt.subplot(1,2,2)
sns.scatterplot(data=df_ventas_final, x="precio_unit", y="valor_venta")
sns.regplot(
    data=df_ventas_final,
    x="precio_unit",
    y="valor_venta",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)
plt.show()

# %% [markdown]
# ### Matríz de correlación

# %%
# Creamos un mapa de calor para representar la matríz de correlación
sns.heatmap(correlacion, annot=True, cmap="coolwarm")

# cmap = coolwarm, Greens, rocket, Reds
plt.show()

# %% [markdown]
# ## 4 - Consolidación de datos

# %% [markdown]
# Consolidar todos los análisis previos y preparar un conjunto de datos final que resuma los hallazgos clave para la presentación.
#
# <BR>
# Aquí intervienen los KPIs, esto es, cuáles son las métricas que le interesan al negocio.
#
# KPIs:
# * **A.** Importe total de ventas concretado por mes
# * **B.** Cantidad de productos totales vendidos por mes
# * **C.** Volumen de venta por categorías
# * **D.** Impacto de la campaña de marketing en las ventas

# %% [markdown]
# ### **A.** &ensp;Importe total de ventas concretado por mes

# %%
# Corramos un head para recordar el dataframe
df_ventas_final.head(10)
# Out:
#    id_venta           producto  precio_unit  cantidad fecha_venta  \
# 0       792  Cuadro decorativo        69.94         5  2024-01-02
# 1       811    Lámpara de mesa       105.10         5  2024-01-02
# 2      1156           Secadora        97.96         3  2024-01-02
# 3      1372           Heladera       114.35         8  2024-01-02
# 4      1546           Secadora       106.21         4  2024-01-02
# 5      1697    Horno eléctrico        35.35         9  2024-01-02
# 6      1710   Plancha de vapor        65.43         2  2024-01-02
# 7      2959          Proyector        88.17         9  2024-01-02
# 8       318  Rincón de plantas        79.86        11  2024-01-03
# 9       419         Candelabro        66.11         8  2024-01-03
#
#            categoria  valor_venta
# 0         Decoración       349.70
# 1         Decoración       525.50
# 2  Electrodomésticos       293.88
# 3  Electrodomésticos       914.80
# 4  Electrodomésticos       424.84
# 5  Electrodomésticos       318.15
# 6  Electrodomésticos       130.86
# 7        Electrónica       793.53
# 8         Decoración       878.46
# 9         Decoración       528.88

# %%
# Generamos primero la columna mes
df_ventas_final["mes"] = df_ventas_final["fecha_venta"].dt.month

# Agrupamos por mes y agregamos por valor_venta
ventas_mes = df_ventas_final.groupby("mes", as_index=False).agg(
    ventas_mes=("valor_venta", "sum")
)

# Renombramos la columna si fuera necesario
# ventas_mes = ventas_mes.rename(columns={
#     "mes": "mes",
#     "ventas_totales": "ventas_totales"
# })

# Visualizamos
ventas_mes.head()
# Out:
#    mes  ventas_mes
# 0    1   129604.99
# 1    2   118672.44
# 2    3   136779.15
# 3    4   128430.69
# 4    5   143727.25

# %% [markdown]
# # cambiar

# %%
# Generamos un gráfico de lineas (serie de tiempo)
# que muestre la evolución de las ventas en el año (2024 por mes)
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set_theme(style="whitegrid", context="talk")
custom_palette = sns.color_palette("Set2") # Aqui pueden cambiar a "Set1", "Set2", "Set3"

# Definimos el tamaño del lienzo
plt.figure(figsize=(10,6))

# Graficamos
sns.lineplot(data=ventas_mes, x="mes", y="ventas_mes", label="Ventas mesuales" )

# Ticks (valores de eje)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Ajustes de título y ejes
plt.title('Ventas mensuales con marca de inicio de campaña', fontsize=14)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas Acumuladas', fontsize=12)
plt.legend(title='Año', fontsize=10, title_fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **B.** &ensp; Cantidad de productos totales vendidos por mes

# %%
# Agrupamos por mes y agregamos por cantidad
cantidades_mes = df_ventas_final.groupby("mes", as_index=False).agg(
    cantidad_mes=("cantidad", "sum")
)

# Visualizamos
cantidades_mes.head()
# Out:
#    mes  cantidad_mes
# 0    1          1741
# 1    2          1607
# 2    3          1792
# 3    4          1715
# 4    5          1812

# %%
# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",          # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set3"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos tamaño del lienzo
plt.figure(figsize=(10,6))

# Crear el barplot
ax = sns.barplot(data=cantidades_mes, x='mes', y='cantidad_mes', label="Ventas 2024", width=0.8)

# Agregar etiquetas arriba de las barras
for i, valor in enumerate(cantidades_mes['cantidad_mes']):
    ax.text(
        i,                       # posición x de la etiqueta
        valor + 10,                   # posición y (ligeramente arriba de la barra)
        str(valor),              # texto
        ha='center', fontsize=10
    )

# Ticks (valores de eje)
plt.tick_params(axis='y', labelsize=9)
plt.tick_params(axis='x', rotation=0,  labelsize=9)

# Ajustes de título y ejes
plt.title('Volúmenes de ventas por productos', fontsize=14)
plt.xlabel('Mes')
plt.ylabel('Cantidades')
plt.legend(loc='upper right', fontsize=10)

# plt.tight_layout() # ajuste automatico
plt.show()

# %% [markdown]
# ### **C.** &ensp; Volumen de venta por categorías

# %%
df_ventas.head()

# Agrupamos por categoría y agregamos por valor_venta
ventas_categoria = df_ventas_final.groupby("categoria", as_index=False).agg(
    ventas_totales=("valor_venta", "sum")
)

# Visualizamos
ventas_categoria.head()
# Out:
#            categoria  ventas_totales
# 0         Decoración       479216.09
# 1  Electrodomésticos       505299.63
# 2        Electrónica       482577.80

# %%
# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",          # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set3"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos tamaño del lienzo
plt.figure(figsize=(8,5))

# Crear el barplot
ax = sns.barplot(data=ventas_categoria, x='categoria', y='ventas_totales', hue='categoria', width=0.5)

# Agregar etiquetas arriba de las barras
for i, valor in enumerate(ventas_categoria['ventas_totales']):
    str_valor = f"{valor:.0f}"
    ax.text(
        i,                      # posición x de la etiqueta
        valor + 10,             # posición y (ligeramente arriba de la barra)
        str_valor,              # texto
        ha='center', fontsize=9
    )

# Ticks (valores de eje)
plt.tick_params(axis='y', labelsize=9)
plt.tick_params(axis='x', labelsize=8)

# Ajustes de título y ejes
plt.title('Volúmenes de ventas por categoría\n', fontsize=14)
plt.xlabel('\nCategorías')
plt.ylabel('Total de ventas')
# plt.legend(loc='upper right', fontsize=10) # Removed this line as seaborn handles the legend with hue

# plt.tight_layout() # ajuste automatico
plt.show()

# %% [markdown]
# .
#
#
#
#
#
#
# .

# %% [markdown]
# ### **D.** &ensp; Impacto de la campaña de marketing en las ventas I

# %% [markdown]
# Trazamos una linea vertical al primer grafico ventas por mes

# %%
# Generamos un gráfico de lineas (serie de tiempo)
# que muestre la evolución de las ventas en el año (2024 por mes)
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set_theme(style="whitegrid", context="talk")
custom_palette = sns.color_palette("Set2") # Aqui pueden cambiar a "Set1", "Set2", "Set3"

# Definimos el tamaño del lienzo
plt.figure(figsize=(10,6))

# Graficamos
sns.lineplot(data=ventas_mes, x="mes", y="ventas_mes", label="Ventas mesuales" )

# línea vertical que marque el inicio de campaña
plt.axvline(3, color="red", linewidth=2, linestyle="--",
            label="Inicio campaña")

# Ticks (valores de eje)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Ajustes de título y ejes
plt.title('Ventas mensuales con marca de inicio de campaña', fontsize=14)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas Acumuladas', fontsize=12)
plt.legend(title='Año', fontsize=10, title_fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **E.** &ensp; Impacto de la campaña de marketing en las ventas **II**

# %% [markdown]
# Revisar la sección Etapa 2 - Integración de datos
# Allí, luego de unir los dataframes df_ventas con df_marketing, se generan 2 dataframes independientes, cada uno conteniendo las ventas que se hicieron dentro de algún período de marketing, y otro con las ventas que se realizaron fuera de campaña.
# <BR>
# Así surgen:
# * ventas_con_marketing_final
# * ventas_sin_marketing_final

# %%
ventas_con_marketing_final.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2730225422.py in <cell line: 0>()
# ----> 1 ventas_con_marketing_final.head()
#
# NameError: name 'ventas_con_marketing_final' is not defined

# %%
ventas_sin_marketing_final.head()

# %%
ventas_con_sin_marketing = pd.merge(ventas_con_marketing_final, ventas_sin_marketing_final, on="producto", how="inner")

ventas_con_sin_marketing = ventas_con_sin_marketing.sort_values(by=["ventas_producto_cm"], ascending=False)

ventas_con_sin_marketing.head()

# %%
# Transformar a formato largo
df_long = ventas_con_sin_marketing[["producto","ventas_producto_cm", "ventas_producto_sm"]]
df_long = df_long.melt(id_vars="producto",
                        var_name="modalidad",
                        value_name="valores")

# df_long = df_long.sort_values(by=["valores", "modalidad"], ascending=True)
df_long.head()

# %%
# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",          # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set3"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos el lienzo
plt.figure(figsize=(8,5))

# Graficamos
sns.barplot(data=df_long, x="producto", y="valores", hue="modalidad", width=0.8)
# sns.barplot(data=df_long, x="Trimestre", y="Ventas", hue="Producto", width=0.8) Invertimos Productos por Trimestre


# Ticks (valores de eje)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(fontsize=8)

# Ajustes de título y ejes
plt.title('Ventas totales por productos dentro y fuera de campaña', fontsize=14)
plt.xlabel('Productos')
plt.ylabel('Ventas')

# Obtener handles (cuadritos de color) y labels originales del gráfico
handles, labels = plt.gca().get_legend_handles_labels()

# Reemplazar solo los textos de la leyenda, manteniendo colores
plt.legend(
    handles,
    ["Fuera de campaña", "Dentro de campaña"],
    title="Modalidad",
    fontsize=9,
    title_fontsize=10
)
plt.tight_layout()
#plt.show()

# %%
ventas_marketing.head()

# %%
df_test = ventas_marketing.groupby(["id_venta", "producto"]).agg(
    {"valor_venta": "first"})
df_test1 = df_test.groupby("producto").agg(
    {"valor_venta": "sum"})

df_test2 = df_test1.sort_values(by="valor_venta", ascending=False)
df_test2.head()

# %% [markdown]
# # Visualización con Plotly

# %% [markdown]
# ## 4 - Presentación Final

# %% [markdown]
# Escribir aquí las observaciones, hallazgos y recomendaciones.

# %% [markdown]
# # ==========================================================

# %% [markdown]
# # ANEXO
#
# ## PROBABLES MEJORAS A FUTURO
#
# ### *Trabajo en curso*
#
# 1 Crear lista categorias = df_ventas_final["categoria"].unique()
#
# 2 Crear tabla df_producto con id_producto, producto, id_categoria, categoria

# %% [markdown]
# Se observó que:
# 1. Las ventas contienen productos con la misma denominación, sin ninguna id como para identificarlos. Pertenecen a distintas ventas individuales y tienen distinto precio.
#
# 2. Por tal razón es dificil hacer una evaluación seria del resultado de la campaña publicitaria, porque corresponde a distintos productos agrupados, con precio sin adjudicar.
#
# 3. La campaña de marketing posee el costo publicitario por producto (generico/agregado) pero no hay como relacionarlo con el costo_unitario, ni con el precio_venta
#
# 4. Sacar un precio_promedio, no estoy seguro que sirva mucho, porque la venta podria haberse hecho a un valor menor que el precio_unitario_promedio, debido a la gran dispersión de precios
#
# Hemos visto que para el producto "Adorno de pared", los precios estan distibuidos en 3 segmentos o rangos, la idea es hacer un promedio por rango y
# luego renombrar los productos segun el rango, por ej:
# "Adorno de pared" => "Adorno de pared R1"
#
# De esta manera en lugar de tener 100 productos genericos los tendriamos divididos por rango de precios y con un nuevo nombre_producto que los represente

# %% [markdown]
# .
#
#
# Borré el código anexo hasta la version definitiva
